# %% [markdown]
# Licensed under the MIT License.
#
# Copyright (c) 2021-2031. All rights reserved.
#
# # Banking Campaign Data

# %%
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## About the Data
#
# * Check data description and <b>download the data</b> from https://www.kaggle.com/code/janiobachmann/bank-marketing-campaign-opening-a-term-deposit/data
#   * Data label is `deposit`, indicating a customer has opened term deposit or not in the campaign
#   * Data Dictionary: https://www.kaggle.com/code/janiobachmann/bank-marketing-campaign-opening-a-term-deposit/notebook

# %%
df = pd.read_csv('bank.csv')
print(df.shape)
print(df.columns)
df.head()
# Out:
# (11162, 17)
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'deposit'],
#       dtype='object')
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# ...

# %%
df.describe(include='all')
# Out:
#                  age         job  marital  education default       balance  \
# count   11162.000000       11162    11162      11162   11162  11162.000000
# unique           NaN          12        3          4       2           NaN
# top              NaN  management  married  secondary      no           NaN
# freq             NaN        2566     6351       5476   10994           NaN
# mean       41.231948         NaN      NaN        NaN     NaN   1528.538524
# std        11.913369         NaN      NaN        NaN     NaN   3225.413326
# min        18.000000         NaN      NaN        NaN     NaN  -6847.000000
# 25%        32.000000         NaN      NaN        NaN     NaN    122.000000
# 50%        39.000000         NaN      NaN        NaN     NaN    550.000000
# 75%        49.000000         NaN      NaN        NaN     NaN   1708.000000
# max        95.000000         NaN      NaN        NaN     NaN  81204.000000
#
# ...

# %%
print(df['job'].value_counts()*100/df.shape[0])
print()
print(df['marital'].value_counts()*100/df.shape[0])
print()
print(df['education'].value_counts()*100/df.shape[0])
print()
print(df['default'].value_counts()*100/df.shape[0])
print()
print(df['housing'].value_counts()*100/df.shape[0])
print()
print(df['loan'].value_counts()*100/df.shape[0])
print()
print(df['contact'].value_counts()*100/df.shape[0])
print()
print(df['month'].value_counts()*100/df.shape[0])
print()
print(df['poutcome'].value_counts()*100/df.shape[0])
print()
print(df['deposit'].value_counts()*100/df.shape[0])
print()
# Out:
# management       22.988712
# blue-collar      17.416234
# technician       16.332199
# admin.           11.951263
# services          8.269127
# retired           6.970077
# self-employed     3.628382
# student           3.225228
# unemployed        3.198352
# entrepreneur      2.938541
# housemaid         2.454757
# unknown           0.627128
# Name: job, dtype: float64
#
# married     56.898405
# single      31.517649
# divorced    11.583946
# Name: marital, dtype: float64
#
# secondary    49.059308
# tertiary     33.049633
# primary      13.438452
# unknown       4.452607
# Name: education, dtype: float64
#
# no     98.494893
# yes     1.505107
# Name: default, dtype: float64
#
# no     52.68769
# yes    47.31231
# Name: housing, dtype: float64
#
# no     86.919907
# yes    13.080093
# Name: loan, dtype: float64
#
# cellular     72.048020
# unknown      21.017739
# telephone     6.934241
# Name: contact, dtype: float64
#
# may    25.300125
# aug    13.608672
# jul    13.563877
# ...

# %%
# check missing value %
df.isnull().sum()/df.shape[0]
# Out:
# age          0.0
# job          0.0
# marital      0.0
# education    0.0
# default      0.0
# balance      0.0
# housing      0.0
# loan         0.0
# contact      0.0
# day          0.0
# month        0.0
# duration     0.0
# campaign     0.0
# pdays        0.0
# previous     0.0
# poutcome     0.0
# deposit      0.0
# dtype: float64

# %%
# convert 'yes', 'no' to 1 and 0
le = preprocessing.LabelEncoder()
df['deposit'] = le.fit_transform(df['deposit'])
print(df['deposit'].value_counts()*100/df.shape[0])
# Out:
# 0    52.616019
# 1    47.383981
# Name: deposit, dtype: float64

# %%
df.to_pickle('structured_data/campaign_deposit.pkl')
