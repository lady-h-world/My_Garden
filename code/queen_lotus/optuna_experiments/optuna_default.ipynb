# %% [markdown]
# Licensed under the MIT License.
#
# Copyright (c) 2021-2025. All rights reserved.
#
# # Optuna Default
#
# * About Optuna
#   * Optuna Github: https://github.com/optuna/optuna
#   * Optuna Examples: https://github.com/optuna/optuna-examples
# * Optuna params depends on models' python libraries
#   * Optuna Integrated LGBM CV params: https://optuna.readthedocs.io/en/stable/reference/generated/optuna.integration.lightgbm.LightGBMTunerCV.html
#   * LGBM params: https://lightgbm.readthedocs.io/en/latest/Parameters.html

# %%
import pandas as pd
import numpy as np
import pickle
import timeit
import matplotlib.pyplot as plt


from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import balanced_accuracy_score
from sklearn.model_selection import cross_val_score

import optuna.integration.lightgbm as lgb
from lightgbm import LGBMClassifier
from optuna.integration import XGBoostPruningCallback
import xgboost as xgb
import optuna

# %%
df30 = pd.read_csv('../../crystal_ball/data_collector/structured_data/leaf.csv')
print(df30.shape)

df30.head()
# Out:
# (340, 16)
#    species  specimen_number  eccentricity  aspect_ratio  elongation  solidity  \
# 0        1                1       0.72694        1.4742     0.32396   0.98535
# 1        1                2       0.74173        1.5257     0.36116   0.98152
# 2        1                3       0.76722        1.5725     0.38998   0.97755
# 3        1                4       0.73797        1.4597     0.35376   0.97566
# 4        1                5       0.82301        1.7707     0.44462   0.97698
#
#    stochastic_convexity  isoperimetric_factor  maximal_indentation_depth  \
# 0               1.00000               0.83592                   0.004657
# 1               0.99825               0.79867                   0.005242
# 2               1.00000               0.80812                   0.007457
# 3               1.00000               0.81697                   0.006877
# 4               1.00000               0.75493                   0.007428
#
#    lobedness  average_intensity  average_contrast  smoothness  third_moment  \
# 0   0.003947           0.047790          0.127950    0.016108      0.005232
# 1   0.005002           0.024160          0.090476    0.008119      0.002708
# 2   0.010121           0.011897          0.057445    0.003289      0.000921
# 3   0.008607           0.015950          0.065491    0.004271      0.001154
# 4   0.010042           0.007938          0.045339    0.002051      0.000560
#
#    uniformity  entropy
# 0    0.000275  1.17560
# 1    0.000075  0.69659
# 2    0.000038  0.44348
# 3    0.000066  0.58785
# 4    0.000024  0.34214

# %%
# Using optuna, multiclass need to adjacent classes
from sklearn import preprocessing

le = preprocessing.LabelEncoder()
df30['species'] = le.fit_transform(df30['species'])

print(min(df30['species']), max(df30['species']))
# Out:
# 0 29

# %%
# train, test split for df30
y30 = df30['species']
X30 = df30.drop('species', axis=1)

X_train30, X_test30, y_train30, y_test30 = train_test_split(X30, y30, test_size=0.2,
                                               random_state=10, shuffle=True, stratify=y30)

X_train30.reset_index(inplace=True, drop=True)
X_test30.reset_index(inplace=True, drop=True)
y_train30.reset_index(inplace=True, drop=True)
y_test30.reset_index(inplace=True, drop=True)

print(X_train30.shape, X_test30.shape, y_train30.shape, y_test30.shape)
print(y_train30.nunique(), y_test30.nunique())
# Out:
# (272, 15) (68, 15) (272,) (68,)
# 30 30

# %% [markdown]
# ## LGBM for df30

# %%
dtrain = lgb.Dataset(X_train30, y_train30)

params = {
    "objective": "multiclass",
    "metric": "multi_logloss",
    "verbosity": -1,
    "num_class": 30,  # have to specify num_class for multiclassification
    "random_state": 10
}

tuner = lgb.LightGBMTunerCV(
    params, 
    dtrain,
    time_budget=300,
    verbose_eval=False,
    folds=StratifiedKFold(n_splits=5, shuffle=True, random_state=10)
)
    
tuner.run()

print("Best score:", tuner.best_score)  # multi_logloss
best_params = tuner.best_params
print("Best params:", best_params)
# Out:
# [I 2021-08-22 22:02:45,989] A new study created in memory with name: no-name-71dc17c0-d0b1-4217-a0ad-4d0abc47ace8
# feature_fraction, val_score: 1.188037:  14%|######4                                      | 1/7 [00:10<01:05, 10.93s/it][I 2021-08-22 22:02:56,932] Trial 0 finished with value: 1.188036985075834 and parameters: {'feature_fraction': 0.6}. Best is trial 0 with value: 1.188036985075834.
# feature_fraction, val_score: 1.188037:  29%|############8                                | 2/7 [00:22<00:55, 11.11s/it][I 2021-08-22 22:03:08,453] Trial 1 finished with value: 1.1899125130468209 and parameters: {'feature_fraction': 0.7}. Best is trial 0 with value: 1.188036985075834.
# feature_fraction, val_score: 1.188037:  43%|###################2                         | 3/7 [00:34<00:45, 11.30s/it][I 2021-08-22 22:03:20,209] Trial 2 finished with value: 1.1919542441263555 and parameters: {'feature_fraction': 0.8}. Best is trial 0 with value: 1.188036985075834.
# feature_fraction, val_score: 1.188037:  57%|#########################7                   | 4/7 [00:45<00:33, 11.30s/it][I 2021-08-22 22:03:31,504] Trial 3 finished with value: 1.22750616826325 and parameters: {'feature_fraction': 1.0}. Best is trial 0 with value: 1.188036985075834.
# feature_fraction, val_score: 1.145788:  71%|################################1            | 5/7 [00:57<00:22, 11.40s/it][I 2021-08-22 22:03:43,124] Trial 4 finished with value: 1.1457880287093116 and parameters: {'feature_fraction': 0.4}. Best is trial 4 with value: 1.1457880287093116.
# feature_fraction, val_score: 1.145788:  86%|######################################5      | 6/7 [01:08<00:11, 11.38s/it][I 2021-08-22 22:03:54,477] Trial 5 finished with value: 1.179834425621199 and parameters: {'feature_fraction': 0.5}. Best is trial 4 with value: 1.1457880287093116.
# feature_fraction, val_score: 1.145788: 100%|#############################################| 7/7 [01:19<00:00, 11.42s/it][I 2021-08-22 22:04:05,997] Trial 6 finished with value: 1.1970686377714066 and parameters: {'feature_fraction': 0.8999999999999999}. Best is trial 4 with value: 1.1457880287093116.
# feature_fraction, val_score: 1.145788: 100%|#############################################| 7/7 [01:20<00:00, 11.43s/it]
# num_leaves, val_score: 1.145788:   5%|##5                                               | 1/20 [00:16<05:16, 16.68s/it][I 2021-08-22 22:04:22,693] Trial 7 finished with value: 1.1457880287093116 and parameters: {'num_leaves': 216}. Best is trial 7 with value: 1.1457880287093116.
# num_leaves, val_score: 1.145788:  10%|#####                                             | 2/20 [00:34<05:04, 16.93s/it][I 2021-08-22 22:04:40,195] Trial 8 finished with value: 1.1457880287093116 and parameters: {'num_leaves': 240}. Best is trial 7 with value: 1.1457880287093116.
# num_leaves, val_score: 1.145788:  15%|#######5                                          | 3/20 [00:48<04:33, 16.07s/it][I 2021-08-22 22:04:54,271] Trial 9 finished with value: 1.1457880287093116 and parameters: {'num_leaves': 130}. Best is trial 7 with value: 1.1457880287093116.
# num_leaves, val_score: 1.145788:  20%|##########                                        | 4/20 [00:59<03:52, 14.55s/it][I 2021-08-22 22:05:05,286] Trial 10 finished with value: 1.1457880287093116 and parameters: {'num_leaves': 34}. Best is trial 7 with value: 1.1457880287093116.
# num_leaves, val_score: 1.145788:  25%|############5                                     | 5/20 [01:17<03:53, 15.60s/it][I 2021-08-22 22:05:23,317] Trial 11 finished with value: 1.1457880287093116 and parameters: {'num_leaves': 237}. Best is trial 7 with value: 1.1457880287093116.
# num_leaves, val_score: 1.145788:  30%|###############                                   | 6/20 [01:27<03:15, 13.95s/it][I 2021-08-22 22:05:33,406] Trial 12 finished with value: 1.1457880287093116 and parameters: {'num_leaves': 27}. Best is trial 7 with value: 1.1457880287093116.
# num_leaves, val_score: 1.145788:  35%|#################5                                | 7/20 [01:40<02:56, 13.60s/it][I 2021-08-22 22:05:46,209] Trial 13 finished with value: 1.1457880287093116 and parameters: {'num_leaves': 36}. Best is trial 7 with value: 1.1457880287093116.
# num_leaves, val_score: 1.145788:  40%|####################                              | 8/20 [01:59<03:02, 15.20s/it][I 2021-08-22 22:06:05,131] Trial 14 finished with value: 1.1457880287093116 and parameters: {'num_leaves': 205}. Best is trial 7 with value: 1.1457880287093116.
# num_leaves, val_score: 1.145788:  45%|######################5                           | 9/20 [02:11<02:37, 14.34s/it][I 2021-08-22 22:06:17,481] Trial 15 finished with value: 1.1457880287093116 and parameters: {'num_leaves': 108}. Best is trial 7 with value: 1.1457880287093116.
# num_leaves, val_score: 1.145788:  50%|########################5                        | 10/20 [02:28<02:30, 15.01s/it][I 2021-08-22 22:06:34,048] Trial 16 finished with value: 1.1457880287093116 and parameters: {'num_leaves': 237}. Best is trial 7 with value: 1.1457880287093116.
# num_leaves, val_score: 1.145788:  55%|##########################9                      | 11/20 [02:42<02:14, 14.89s/it][I 2021-08-22 22:06:48,657] Trial 17 finished with value: 1.1457880287093116 and parameters: {'num_leaves': 170}. Best is trial 7 with value: 1.1457880287093116.
# num_leaves, val_score: 1.145788:  60%|#############################4                   | 12/20 [03:00<02:05, 15.74s/it][I 2021-08-22 22:07:06,383] Trial 18 finished with value: 1.1457880287093116 and parameters: {'num_leaves': 252}. Best is trial 7 with value: 1.1457880287093116.
# num_leaves, val_score: 1.145788:  65%|###############################8                 | 13/20 [03:16<01:51, 15.93s/it][I 2021-08-22 22:07:22,755] Trial 19 finished with value: 1.1457880287093116 and parameters: {'num_leaves': 190}. Best is trial 7 with value: 1.1457880287093116.
# num_leaves, val_score: 1.145788:  70%|##################################3              | 14/20 [03:32<01:34, 15.83s/it][I 2021-08-22 22:07:38,359] Trial 20 finished with value: 1.1457880287093116 and parameters: {'num_leaves': 138}. Best is trial 7 with value: 1.1457880287093116.
# num_leaves, val_score: 1.145788:  75%|####################################7            | 15/20 [03:52<01:25, 17.14s/it][I 2021-08-22 22:07:58,540] Trial 21 finished with value: 1.1457880287093116 and parameters: {'num_leaves': 212}. Best is trial 7 with value: 1.1457880287093116.
# num_leaves, val_score: 1.145788:  75%|####################################7            | 15/20 [03:52<01:17, 15.50s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# Best score: 1.1457880287093116
# Best params: {'objective': 'multiclass', 'metric': 'multi_logloss', 'verbosity': -1, 'num_class': 30, 'random_state': 10, 'feature_pre_filter': False, 'lambda_l1': 0.0, 'lambda_l2': 0.0, 'num_leaves': 31, 'feature_fraction': 0.4, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20}

# %%
model = LGBMClassifier(objective='multiclass', metric='multi_logloss', num_class= 30, 
                        random_state= 10, feature_pre_filter= False, lambda_l1= 0.0, lambda_l2= 0.0, num_leaves= 31,
                        feature_fraction= 0.4, bagging_fraction= 1.0, bagging_freq= 0, min_child_samples= 20)
model.fit(X_train30, y_train30)
y_pred30 = model.predict(X_test30)

balanced_accuracy = balanced_accuracy_score(y_test30, y_pred30)
print(f'The balanced accuracy on testing data from optimized model is {balanced_accuracy}')
# Out:
# The balanced accuracy on testing data from optimized model is 0.7777777777777778

# %% [markdown]
# ## Multiple Estimators for df100
#
# * Tips of Optuna Search Algorithms (Samplers): https://optuna.readthedocs.io/en/stable/tutorial/10_key_features/003_efficient_optimization_algorithms.html#which-sampler-and-pruner-should-be-used
# * Optuna LGBM: https://optuna.readthedocs.io/en/stable/reference/generated/optuna.integration.lightgbm.LightGBMTunerCV.html
# * Optuna XGBoost: https://optuna.readthedocs.io/en/stable/reference/generated/optuna.integration.XGBoostPruningCallback.html#optuna.integration.XGBoostPruningCallback
#   * xgboost.cv: https://xgboost.readthedocs.io/en/latest/python/python_api.html#xgboost.cv

# %%
df100 = pd.read_csv('../../crystal_ball/data_collector/structured_data/100leaves.csv')
print(df100.shape)

df100.head()
# Out:
# (1599, 193)
#       Mar_1     Mar_2     Mar_3     Mar_4     Mar_5     Mar_6     Mar_7  \
# 0  0.003906  0.003906  0.027344  0.033203  0.007812  0.017578  0.023438
# 1  0.017578  0.011719  0.023438  0.019531  0.003906  0.011719  0.015625
# 2  0.009766  0.021484  0.019531  0.027344  0.003906  0.025391  0.023438
# 3  0.015625  0.009766  0.025391  0.027344  0.001953  0.001953  0.011719
# 4  0.017578  0.041016  0.017578  0.005859  0.003906  0.027344  0.017578
#
#       Mar_8     Mar_9    Mar_10  ...  Tex_56    Tex_57    Tex_58    Tex_59  \
# 0  0.005859  0.000000  0.015625  ...     0.0  0.001953  0.000977  0.022461
# 1  0.000000  0.000000  0.031250  ...     0.0  0.010742  0.000000  0.007812
# 2  0.000000  0.001953  0.023438  ...     0.0  0.019531  0.000000  0.003906
# 3  0.000000  0.001953  0.013672  ...     0.0  0.000977  0.000000  0.021484
# 4  0.003906  0.000000  0.017578  ...     0.0  0.003906  0.000000  0.012695
#
#    Tex_60  Tex_61    Tex_62  Tex_63    Tex_64  species_int
# 0     0.0     0.0  0.001953     0.0  0.027344            0
# 1     0.0     0.0  0.000000     0.0  0.021484            0
# 2     0.0     0.0  0.000000     0.0  0.012695            0
# 3     0.0     0.0  0.000000     0.0  0.014648            0
# 4     0.0     0.0  0.000000     0.0  0.004883            0
#
# [5 rows x 193 columns]

# %%
# train, test split for df100
y100 = df100['species_int']
X100 = df100.drop('species_int', axis=1)

X_train100, X_test100, y_train100, y_test100 = train_test_split(X100, y100, test_size=0.2,
                                               random_state=10, shuffle=True, stratify=y100)

X_train100.reset_index(inplace=True, drop=True)
X_test100.reset_index(inplace=True, drop=True)
y_train100.reset_index(inplace=True, drop=True)
y_test100.reset_index(inplace=True, drop=True)

print(X_train100.shape, X_test100.shape, y_train100.shape, y_test100.shape)
print(y_train100.nunique(), y_test100.nunique())
# Out:
# (1279, 192) (320, 192) (1279,) (320,)
# 100 100

# %%
# define the objective function with multiple estimators
def objective(trial):
    classifier = trial.suggest_categorical('classifier', ['XGBoost', 'LightGBM'])
    
    if classifier == 'LightGBM':
        dtrain100 = lgb.Dataset(X_train100, y_train100)
        
        params = {
            "objective": "multiclass",
            "metric": "multi_logloss",
            "verbosity": -1,
            "num_class": 100, 
            "random_state": 10
        }

        tuner = lgb.LightGBMTunerCV(
            params, 
            dtrain100,
            time_budget=100,
            verbose_eval=False,
            folds=StratifiedKFold(n_splits=10, shuffle=True, random_state=10)
        )
        tuner.run()
        return tuner.best_score

    else:
        dtrain100 = xgb.DMatrix(X_train100, y_train100)
        
        params = {
            "objective": "multi:softmax",
            "metric": "mlogloss",
            "verbosity": 0,
            "num_class": 100, 
            "random_state": 10,
            "stratified": True,
            "nfold": 10
        }
        
        pruning_callback = optuna.integration.XGBoostPruningCallback(trial, "test-mlogloss")
        history = xgb.cv(params, dtrain100, callbacks=[pruning_callback], seed=10) 
        
        return history['test-mlogloss-mean'].values[-1]  # also return the best score

# %% [markdown]
# ### Defualt Search Algorithm (Sampler) - TPE

# %%
start = timeit.default_timer()

study = optuna.create_study(direction="minimize")
print(f"Default sampler is {study.sampler.__class__.__name__}")
study.optimize(objective, n_trials=12)

print("Number of finished trials: {}".format(len(study.trials)))
print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
    

stop = timeit.default_timer()
print('Time: ', stop - start)
# Out:
# [I 2021-08-27 23:58:27,098] A new study created in memory with name: no-name-60afe879-852f-49d1-bcc9-d0bc17dae895
# Default sampler is TPESampler
# [I 2021-08-27 23:58:32,290] Trial 0 finished with value: 1.503399 and parameters: {'classifier': 'XGBoost'}. Best is trial 0 with value: 1.503399.
# [I 2021-08-27 23:58:32,290] A new study created in memory with name: no-name-edba627d-1e1f-40ce-9bf3-5c620c63e525
# feature_fraction, val_score: 0.566254:  14%|######2                                     | 1/7 [06:11<37:08, 371.42s/it][I 2021-08-28 00:04:43,744] Trial 0 finished with value: 0.5662536860145171 and parameters: {'feature_fraction': 1.0}. Best is trial 0 with value: 0.5662536860145171.
# feature_fraction, val_score: 0.566254:  14%|######2                                     | 1/7 [06:11<37:08, 371.44s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# [I 2021-08-28 00:04:43,799] Trial 1 finished with value: 0.5662536860145171 and parameters: {'classifier': 'LightGBM'}. Best is trial 1 with value: 0.5662536860145171.
# [I 2021-08-28 00:04:52,171] Trial 2 finished with value: 1.503399 and parameters: {'classifier': 'XGBoost'}. Best is trial 1 with value: 0.5662536860145171.
# [I 2021-08-28 00:04:52,186] A new study created in memory with name: no-name-906e2ee8-6afd-4db6-b315-06d6fa4fa97c
# feature_fraction, val_score: 0.553620:  14%|######                                    | 1/7 [11:04<1:06:28, 664.72s/it][I 2021-08-28 00:15:56,932] Trial 0 finished with value: 0.5536195459340668 and parameters: {'feature_fraction': 0.8999999999999999}. Best is trial 0 with value: 0.5536195459340668.
# feature_fraction, val_score: 0.553620:  14%|######                                    | 1/7 [11:04<1:06:28, 664.73s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# [I 2021-08-28 00:15:56,981] Trial 3 finished with value: 0.5536195459340668 and parameters: {'classifier': 'LightGBM'}. Best is trial 3 with value: 0.5536195459340668.
# [I 2021-08-28 00:15:56,983] A new study created in memory with name: no-name-e9b30a40-f6df-4481-b2a4-d4e82faf32c9
# feature_fraction, val_score: 0.566254:  14%|######                                    | 1/7 [11:12<1:07:13, 672.31s/it][I 2021-08-28 00:27:09,318] Trial 0 finished with value: 0.5662536860145171 and parameters: {'feature_fraction': 1.0}. Best is trial 0 with value: 0.5662536860145171.
# feature_fraction, val_score: 0.566254:  14%|######                                    | 1/7 [11:12<1:07:13, 672.33s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# [I 2021-08-28 00:27:09,372] Trial 4 finished with value: 0.5662536860145171 and parameters: {'classifier': 'LightGBM'}. Best is trial 3 with value: 0.5536195459340668.
# [I 2021-08-28 00:27:18,715] Trial 5 finished with value: 1.503399 and parameters: {'classifier': 'XGBoost'}. Best is trial 3 with value: 0.5536195459340668.
# [I 2021-08-28 00:27:28,163] Trial 6 finished with value: 1.503399 and parameters: {'classifier': 'XGBoost'}. Best is trial 3 with value: 0.5536195459340668.
# [I 2021-08-28 00:27:28,163] A new study created in memory with name: no-name-85e3e02b-bba9-4e05-aaa1-2c3b29b0606f
# feature_fraction, val_score: 0.566254:  14%|######                                    | 1/7 [10:57<1:05:47, 657.93s/it][I 2021-08-28 00:38:26,121] Trial 0 finished with value: 0.5662536860145171 and parameters: {'feature_fraction': 1.0}. Best is trial 0 with value: 0.5662536860145171.
# feature_fraction, val_score: 0.566254:  14%|######                                    | 1/7 [10:57<1:05:47, 657.94s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# [I 2021-08-28 00:38:26,178] Trial 7 finished with value: 0.5662536860145171 and parameters: {'classifier': 'LightGBM'}. Best is trial 3 with value: 0.5536195459340668.
# [I 2021-08-28 00:38:26,186] A new study created in memory with name: no-name-12bb6d1b-c0ac-488c-bd07-f745909e8a7e
# feature_fraction, val_score: 0.431213:  14%|######                                    | 1/7 [10:09<1:00:55, 609.30s/it][I 2021-08-28 00:48:35,510] Trial 0 finished with value: 0.43121294760070084 and parameters: {'feature_fraction': 0.5}. Best is trial 0 with value: 0.43121294760070084.
# feature_fraction, val_score: 0.431213:  14%|######                                    | 1/7 [10:09<1:00:55, 609.32s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# [I 2021-08-28 00:48:35,562] Trial 8 finished with value: 0.43121294760070084 and parameters: {'classifier': 'LightGBM'}. Best is trial 8 with value: 0.43121294760070084.
# [I 2021-08-28 00:48:45,942] Trial 9 finished with value: 1.503399 and parameters: {'classifier': 'XGBoost'}. Best is trial 8 with value: 0.43121294760070084.
# [I 2021-08-28 00:48:45,942] A new study created in memory with name: no-name-400c5248-56d5-4a86-b965-c5bb94790ebd
# feature_fraction, val_score: 0.447473:  14%|######2                                     | 1/7 [09:54<59:28, 594.82s/it][I 2021-08-28 00:58:40,796] Trial 0 finished with value: 0.44747315832570217 and parameters: {'feature_fraction': 0.6}. Best is trial 0 with value: 0.44747315832570217.
# feature_fraction, val_score: 0.447473:  14%|######2                                     | 1/7 [09:54<59:28, 594.83s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# [I 2021-08-28 00:58:40,844] Trial 10 finished with value: 0.44747315832570217 and parameters: {'classifier': 'LightGBM'}. Best is trial 8 with value: 0.43121294760070084.
# [I 2021-08-28 00:58:40,847] A new study created in memory with name: no-name-fbcf30aa-f568-4eef-a704-0cce7ddc1e0e
# feature_fraction, val_score: 0.447473:  14%|######2                                     | 1/7 [09:25<56:30, 565.06s/it][I 2021-08-28 01:08:05,930] Trial 0 finished with value: 0.44747315832570217 and parameters: {'feature_fraction': 0.6}. Best is trial 0 with value: 0.44747315832570217.
# feature_fraction, val_score: 0.447473:  14%|######2                                     | 1/7 [09:25<56:30, 565.08s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# [I 2021-08-28 01:08:05,981] Trial 11 finished with value: 0.44747315832570217 and parameters: {'classifier': 'LightGBM'}. Best is trial 8 with value: 0.43121294760070084.
# Number of finished trials: 12
# Best trial:
#   Value: 0.43121294760070084
#   Params:
#     classifier: LightGBM
# Time:  4178.8889868

# %%
model = LGBMClassifier(objective='multiclass', metric='multi_logloss', num_class= 100, 
                        random_state= 10)
model.fit(X_train100, y_train100)
y_pred100 = model.predict(X_test100)

balanced_accuracy = balanced_accuracy_score(y_test100, y_pred100)
print(f'The balanced accuracy on testing data from selected model is {balanced_accuracy}')
# Out:
# The balanced accuracy on testing data from selected model is 0.8916666666666667

# %% [markdown]
# ### Random Search Sampler

# %%
sampler = optuna.samplers.RandomSampler()

start = timeit.default_timer()

study = optuna.create_study(direction="minimize", sampler=sampler)
print(f"Default sampler is {study.sampler.__class__.__name__}")
study.optimize(objective, n_trials=12)

print("Number of finished trials: {}".format(len(study.trials)))
print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
    

stop = timeit.default_timer()
print('Time: ', stop - start)
# Out:
# [I 2021-08-28 08:59:25,803] A new study created in memory with name: no-name-8c1b054b-03ec-492a-9ec9-1ea88f0efc06
# Default sampler is RandomSampler
# [I 2021-08-28 08:59:34,404] Trial 0 finished with value: 1.503399 and parameters: {'classifier': 'XGBoost'}. Best is trial 0 with value: 1.503399.
# [I 2021-08-28 08:59:42,879] Trial 1 finished with value: 1.503399 and parameters: {'classifier': 'XGBoost'}. Best is trial 0 with value: 1.503399.
# [I 2021-08-28 08:59:42,882] A new study created in memory with name: no-name-4d2ea513-4449-442b-8daf-6c89290ae25f
# feature_fraction, val_score: 0.447473:  14%|######2                                     | 1/7 [08:47<52:44, 527.48s/it][I 2021-08-28 09:08:30,372] Trial 0 finished with value: 0.44747315832570217 and parameters: {'feature_fraction': 0.6}. Best is trial 0 with value: 0.44747315832570217.
# feature_fraction, val_score: 0.447473:  14%|######2                                     | 1/7 [08:47<52:44, 527.48s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# [I 2021-08-28 09:08:30,408] Trial 2 finished with value: 0.44747315832570217 and parameters: {'classifier': 'LightGBM'}. Best is trial 2 with value: 0.44747315832570217.
# [I 2021-08-28 09:08:39,971] Trial 3 finished with value: 1.503399 and parameters: {'classifier': 'XGBoost'}. Best is trial 2 with value: 0.44747315832570217.
# [I 2021-08-28 09:08:49,513] Trial 4 finished with value: 1.503399 and parameters: {'classifier': 'XGBoost'}. Best is trial 2 with value: 0.44747315832570217.
# [I 2021-08-28 09:08:49,513] A new study created in memory with name: no-name-9ec3c711-7073-48ac-a189-d2e3fe9a528a
# feature_fraction, val_score: 0.431213:  14%|######                                    | 1/7 [10:54<1:05:24, 654.05s/it][I 2021-08-28 09:19:43,585] Trial 0 finished with value: 0.43121294760070084 and parameters: {'feature_fraction': 0.5}. Best is trial 0 with value: 0.43121294760070084.
# feature_fraction, val_score: 0.431213:  14%|######                                    | 1/7 [10:54<1:05:24, 654.07s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# [I 2021-08-28 09:19:43,679] Trial 5 finished with value: 0.43121294760070084 and parameters: {'classifier': 'LightGBM'}. Best is trial 5 with value: 0.43121294760070084.
# [I 2021-08-28 09:19:43,679] A new study created in memory with name: no-name-b7bd9620-b780-46fe-84c6-74d2560c6d4e
# feature_fraction, val_score: 0.536330:  14%|######                                    | 1/7 [11:32<1:09:12, 692.08s/it][I 2021-08-28 09:31:15,777] Trial 0 finished with value: 0.5363297071080304 and parameters: {'feature_fraction': 0.8}. Best is trial 0 with value: 0.5363297071080304.
# feature_fraction, val_score: 0.536330:  14%|######                                    | 1/7 [11:32<1:09:12, 692.09s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# [I 2021-08-28 09:31:15,865] Trial 6 finished with value: 0.5363297071080304 and parameters: {'classifier': 'LightGBM'}. Best is trial 5 with value: 0.43121294760070084.
# [I 2021-08-28 09:31:26,663] Trial 7 finished with value: 1.503399 and parameters: {'classifier': 'XGBoost'}. Best is trial 5 with value: 0.43121294760070084.
# [I 2021-08-28 09:31:26,677] A new study created in memory with name: no-name-a528aa24-37c9-4027-9591-e9e3d98257b4
# feature_fraction, val_score: 0.384398:  14%|######                                    | 1/7 [10:51<1:05:11, 651.96s/it][I 2021-08-28 09:42:18,666] Trial 0 finished with value: 0.38439777744004855 and parameters: {'feature_fraction': 0.4}. Best is trial 0 with value: 0.38439777744004855.
# feature_fraction, val_score: 0.384398:  14%|######                                    | 1/7 [10:51<1:05:11, 651.98s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# [I 2021-08-28 09:42:18,758] Trial 8 finished with value: 0.38439777744004855 and parameters: {'classifier': 'LightGBM'}. Best is trial 8 with value: 0.38439777744004855.
# [I 2021-08-28 09:42:18,759] A new study created in memory with name: no-name-dff47928-ee44-489e-8ce4-ffbb10fee0fa
# feature_fraction, val_score: 0.384398:  14%|######                                    | 1/7 [10:53<1:05:19, 653.26s/it][I 2021-08-28 09:53:12,049] Trial 0 finished with value: 0.38439777744004855 and parameters: {'feature_fraction': 0.4}. Best is trial 0 with value: 0.38439777744004855.
# feature_fraction, val_score: 0.384398:  14%|######                                    | 1/7 [10:53<1:05:19, 653.28s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# [I 2021-08-28 09:53:12,130] Trial 9 finished with value: 0.38439777744004855 and parameters: {'classifier': 'LightGBM'}. Best is trial 8 with value: 0.38439777744004855.
# [I 2021-08-28 09:53:12,134] A new study created in memory with name: no-name-e9786c66-ec4c-4301-a43b-5280216ee29c
# feature_fraction, val_score: 0.384398:  14%|######                                    | 1/7 [10:48<1:04:53, 648.99s/it][I 2021-08-28 10:04:01,149] Trial 0 finished with value: 0.38439777744004855 and parameters: {'feature_fraction': 0.4}. Best is trial 0 with value: 0.38439777744004855.
# feature_fraction, val_score: 0.384398:  14%|######                                    | 1/7 [10:48<1:04:53, 649.00s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# [I 2021-08-28 10:04:01,228] Trial 10 finished with value: 0.38439777744004855 and parameters: {'classifier': 'LightGBM'}. Best is trial 8 with value: 0.38439777744004855.
# [I 2021-08-28 10:04:12,061] Trial 11 finished with value: 1.503399 and parameters: {'classifier': 'XGBoost'}. Best is trial 8 with value: 0.38439777744004855.
# Number of finished trials: 12
# Best trial:
#   Value: 0.38439777744004855
#   Params:
#     classifier: LightGBM
# Time:  3886.280057
