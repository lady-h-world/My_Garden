# %% [markdown]
# Licensed under the MIT License.
#
# Copyright (c) 2021-2025. All rights reserved.
#
# # Optuna Specified Search Space with Integrated CV
#
# * Using Optuna integrated CV

# %%
import pandas as pd
import timeit

from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import balanced_accuracy_score
from sklearn import preprocessing

import optuna.integration.lightgbm as lgb
from lightgbm import LGBMClassifier
import optuna

import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
df30 = pd.read_csv('../../crystal_ball/data_collector/structured_data/leaf.csv')
print(df30.shape)

df30.head()
# Out:
# (340, 16)
#    species  specimen_number  eccentricity  aspect_ratio  elongation  solidity  \
# 0        1                1       0.72694        1.4742     0.32396   0.98535
# 1        1                2       0.74173        1.5257     0.36116   0.98152
# 2        1                3       0.76722        1.5725     0.38998   0.97755
# 3        1                4       0.73797        1.4597     0.35376   0.97566
# 4        1                5       0.82301        1.7707     0.44462   0.97698
#
#    stochastic_convexity  isoperimetric_factor  maximal_indentation_depth  \
# 0               1.00000               0.83592                   0.004657
# 1               0.99825               0.79867                   0.005242
# 2               1.00000               0.80812                   0.007457
# 3               1.00000               0.81697                   0.006877
# 4               1.00000               0.75493                   0.007428
#
#    lobedness  average_intensity  average_contrast  smoothness  third_moment  \
# 0   0.003947           0.047790          0.127950    0.016108      0.005232
# 1   0.005002           0.024160          0.090476    0.008119      0.002708
# 2   0.010121           0.011897          0.057445    0.003289      0.000921
# 3   0.008607           0.015950          0.065491    0.004271      0.001154
# 4   0.010042           0.007938          0.045339    0.002051      0.000560
#
#    uniformity  entropy
# 0    0.000275  1.17560
# 1    0.000075  0.69659
# 2    0.000038  0.44348
# 3    0.000066  0.58785
# 4    0.000024  0.34214

# %%
# Using optuna, multiclass need to adjacent classes
le = preprocessing.LabelEncoder()
df30['species'] = le.fit_transform(df30['species'])


# train, test split for df30
y30 = df30['species']
X30 = df30.drop('species', axis=1)

X_train30, X_test30, y_train30, y_test30 = train_test_split(X30, y30, test_size=0.2,
                                               random_state=10, shuffle=True, stratify=y30)

X_train30.reset_index(inplace=True, drop=True)
X_test30.reset_index(inplace=True, drop=True)
y_train30.reset_index(inplace=True, drop=True)
y_test30.reset_index(inplace=True, drop=True)

print(X_train30.shape, X_test30.shape, y_train30.shape, y_test30.shape)
print(y_train30.nunique(), y_test30.nunique())
# Out:
# (272, 15) (68, 15) (272,) (68,)
# 30 30

# %% [markdown]
# ## Without Pruner for Leaves30
# * LGBM params: https://lightgbm.readthedocs.io/en/latest/Parameters.html
# * Params used in Optuna's integrated LGBM CV: https://optuna.readthedocs.io/en/stable/reference/generated/optuna.integration.lightgbm.LightGBMTunerCV.html
# * Optuna trial methods: https://optuna.readthedocs.io/en/stable/reference/generated/optuna.trial.Trial.html#optuna.trial.Trial
# * Without pruner

# %%
def objective(trial):
    dtrain = lgb.Dataset(X_train30, y_train30)
    upper = min(32768, int(X_train30.shape[0]))
        
    params = {
        "objective": "multiclass",
        "metric": "multi_logloss",
        "num_class": 30, 
        "random_state": 10,
        "verbosity": -1,
        
        # specify the similar search space as FLAML, but optuna has no initial value to suggest
        "num_leaves": trial.suggest_int("num_leaves", 4, upper),
        "learning_rate": trial.suggest_loguniform("learning_rate", 1/1024, 1.0),
        "subsample": trial.suggest_uniform("subsample", 0.1, 1.0),
        "max_bin": trial.suggest_int("max_bin", 3, 10),
        "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.01, 1.0),
        "reg_alpha": trial.suggest_loguniform("reg_alpha", 1/1024, 1024),
        "reg_lambda": trial.suggest_loguniform("reg_lambda", 1/1024, 1024),
        "max_depth": trial.suggest_int("max_depth", 2, 10),
        "extra_trees": True
    }

    tuner = lgb.LightGBMTunerCV(
        params, 
        dtrain,
        time_budget=100,
        verbose_eval=False,
        folds=StratifiedKFold(n_splits=5, shuffle=True, random_state=10),
        verbosity=-1
    )
    
    tuner.run()
    return tuner.best_score

# %%
start = timeit.default_timer()

study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=10)

print("Number of finished trials: {}".format(len(study.trials)))
print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
    
stop = timeit.default_timer()
print('Time: ', stop - start)
# Out:
# [I 2021-08-28 18:01:17,303] A new study created in memory with name: no-name-b558219f-fd64-46fe-8ff7-27fe794b97aa
# [I 2021-08-28 18:01:17,311] A new study created in memory with name: no-name-49141714-556d-48d3-a8a7-f9b64ab2dc86
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
#
#
#
#
#
#   0%|                                                                                            | 0/7 [00:00<?, ?it/s]
#
#
#
#
# feature_fraction, val_score: inf:   0%|                                                          | 0/7 [00:00<?, ?it/s]
#
#
#
#
# feature_fraction, val_score: 3.426870:   0%|                                                     | 0/7 [00:04<?, ?it/s]
#
#
#
#
# feature_fraction, val_score: 3.426870:  14%|######4                                      | 1/7 [00:04<00:28,  4.71s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  14%|######4                                      | 1/7 [00:04<00:28,  4.71s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  14%|######4                                      | 1/7 [00:09<00:28,  4.71s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  29%|############8                                | 2/7 [00:09<00:23,  4.71s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  29%|############8                                | 2/7 [00:09<00:23,  4.71s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  29%|############8                                | 2/7 [00:14<00:23,  4.71s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  43%|###################2                         | 3/7 [00:14<00:18,  4.68s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  43%|###################2                         | 3/7 [00:14<00:18,  4.68s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  43%|###################2                         | 3/7 [00:18<00:18,  4.68s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  57%|#########################7                   | 4/7 [00:18<00:13,  4.66s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  57%|#########################7                   | 4/7 [00:18<00:13,  4.66s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  57%|#########################7                   | 4/7 [00:24<00:13,  4.66s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  71%|################################1            | 5/7 [00:24<00:10,  5.04s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  71%|################################1            | 5/7 [00:24<00:10,  5.04s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  71%|################################1            | 5/7 [00:30<00:10,  5.04s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  86%|######################################5      | 6/7 [00:30<00:05,  5.25s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  86%|######################################5      | 6/7 [00:30<00:05,  5.25s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  86%|######################################5      | 6/7 [00:36<00:05,  5.25s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870: 100%|#############################################| 7/7 [00:36<00:00,  5.16s/it]
#
#
#
#
#
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#
#
#
#
# num_leaves, val_score: 3.426870:   0%|                                                          | 0/20 [00:00<?, ?it/s]
#
#
#
#
# num_leaves, val_score: 3.426870:   0%|                                                          | 0/20 [00:05<?, ?it/s]
#
#
#
#
# num_leaves, val_score: 3.426870:   5%|##5                                               | 1/20 [00:05<01:42,  5.41s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:   5%|##5                                               | 1/20 [00:05<01:42,  5.41s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:   5%|##5                                               | 1/20 [00:10<01:42,  5.41s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  10%|#####                                             | 2/20 [00:10<01:37,  5.40s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  10%|#####                                             | 2/20 [00:10<01:37,  5.40s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  10%|#####                                             | 2/20 [00:15<01:37,  5.40s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  15%|#######5                                          | 3/20 [00:15<01:29,  5.27s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  15%|#######5                                          | 3/20 [00:15<01:29,  5.27s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  15%|#######5                                          | 3/20 [00:21<01:29,  5.27s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  20%|##########                                        | 4/20 [00:21<01:25,  5.36s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  20%|##########                                        | 4/20 [00:21<01:25,  5.36s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  20%|##########                                        | 4/20 [00:29<01:25,  5.36s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  25%|############5                                     | 5/20 [00:29<01:31,  6.10s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  25%|############5                                     | 5/20 [00:29<01:31,  6.10s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  25%|############5                                     | 5/20 [00:37<01:31,  6.10s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  30%|###############                                   | 6/20 [00:37<01:33,  6.70s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  30%|###############                                   | 6/20 [00:37<01:33,  6.70s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  30%|###############                                   | 6/20 [00:47<01:33,  6.70s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  35%|#################5                                | 7/20 [00:47<01:39,  7.68s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  35%|#################5                                | 7/20 [00:47<01:39,  7.68s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  35%|#################5                                | 7/20 [00:57<01:39,  7.68s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  40%|####################                              | 8/20 [00:57<01:42,  8.51s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  40%|####################                              | 8/20 [00:57<01:42,  8.51s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  40%|####################                              | 8/20 [01:08<01:42,  8.51s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  45%|######################5                           | 9/20 [01:08<01:23,  7.60s/it]
#
#
#
#
#
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
#
#
#
#
#
#   0%|                                                                                            | 0/7 [00:00<?, ?it/s]
#
#
#
#
# feature_fraction, val_score: inf:   0%|                                                          | 0/7 [00:00<?, ?it/s]
#
#
#
#
# feature_fraction, val_score: 3.426870:   0%|                                                     | 0/7 [00:11<?, ?it/s]
#
#
#
#
# feature_fraction, val_score: 3.426870:  14%|######4                                      | 1/7 [00:11<01:08, 11.34s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  14%|######4                                      | 1/7 [00:11<01:08, 11.34s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  14%|######4                                      | 1/7 [00:22<01:08, 11.34s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  29%|############8                                | 2/7 [00:22<00:56, 11.38s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  29%|############8                                | 2/7 [00:22<00:56, 11.38s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  29%|############8                                | 2/7 [00:34<00:56, 11.38s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  43%|###################2                         | 3/7 [00:34<00:45, 11.34s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  43%|###################2                         | 3/7 [00:34<00:45, 11.34s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  43%|###################2                         | 3/7 [00:44<00:45, 11.34s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  57%|#########################7                   | 4/7 [00:44<00:33, 11.13s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  57%|#########################7                   | 4/7 [00:44<00:33, 11.13s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  57%|#########################7                   | 4/7 [00:55<00:33, 11.13s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  71%|################################1            | 5/7 [00:55<00:21, 10.99s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  71%|################################1            | 5/7 [00:55<00:21, 10.99s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  71%|################################1            | 5/7 [01:07<00:21, 10.99s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  86%|######################################5      | 6/7 [01:07<00:11, 11.40s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  86%|######################################5      | 6/7 [01:07<00:11, 11.40s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  86%|######################################5      | 6/7 [01:17<00:11, 11.40s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870: 100%|#############################################| 7/7 [01:17<00:00, 11.04s/it]
#
#
#
#
#
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#
#
#
#
# num_leaves, val_score: 3.426870:   0%|                                                          | 0/20 [00:00<?, ?it/s]
#
#
#
#
# num_leaves, val_score: 3.426870:   0%|                                                          | 0/20 [00:08<?, ?it/s]
#
#
#
#
# num_leaves, val_score: 3.426870:   5%|##5                                               | 1/20 [00:08<02:36,  8.26s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:   5%|##5                                               | 1/20 [00:08<02:36,  8.26s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:   5%|##5                                               | 1/20 [00:15<02:36,  8.26s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  10%|#####                                             | 2/20 [00:15<02:25,  8.07s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  10%|#####                                             | 2/20 [00:15<02:25,  8.07s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  10%|#####                                             | 2/20 [00:23<02:25,  8.07s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  15%|#######5                                          | 3/20 [00:23<02:14,  7.94s/it]
#
#
#
#
#
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
#
#
#
#
#
#   0%|                                                                                            | 0/7 [00:00<?, ?it/s]
#
#
#
#
# feature_fraction, val_score: inf:   0%|                                                          | 0/7 [00:00<?, ?it/s]
#
#
#
#
# feature_fraction, val_score: 3.426870:   0%|                                                     | 0/7 [00:09<?, ?it/s]
#
#
#
#
# feature_fraction, val_score: 3.426870:  14%|######4                                      | 1/7 [00:09<00:56,  9.37s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  14%|######4                                      | 1/7 [00:09<00:56,  9.37s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  14%|######4                                      | 1/7 [00:17<00:56,  9.37s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  29%|############8                                | 2/7 [00:17<00:45,  9.12s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  29%|############8                                | 2/7 [00:17<00:45,  9.12s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  29%|############8                                | 2/7 [00:25<00:45,  9.12s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  43%|###################2                         | 3/7 [00:25<00:34,  8.63s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  43%|###################2                         | 3/7 [00:25<00:34,  8.63s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  43%|###################2                         | 3/7 [00:34<00:34,  8.63s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  57%|#########################7                   | 4/7 [00:34<00:26,  8.75s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  57%|#########################7                   | 4/7 [00:34<00:26,  8.75s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  57%|#########################7                   | 4/7 [00:42<00:26,  8.75s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  71%|################################1            | 5/7 [00:42<00:16,  8.43s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  71%|################################1            | 5/7 [00:42<00:16,  8.43s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  71%|################################1            | 5/7 [00:49<00:16,  8.43s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  86%|######################################5      | 6/7 [00:49<00:08,  8.05s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  86%|######################################5      | 6/7 [00:49<00:08,  8.05s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  86%|######################################5      | 6/7 [00:57<00:08,  8.05s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870: 100%|#############################################| 7/7 [00:57<00:00,  8.20s/it]
#
#
#
#
#
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#
#
#
#
# num_leaves, val_score: 3.426870:   0%|                                                          | 0/20 [00:00<?, ?it/s]
#
#
#
#
# num_leaves, val_score: 3.426870:   0%|                                                          | 0/20 [00:07<?, ?it/s]
#
#
#
#
# num_leaves, val_score: 3.426870:   5%|##5                                               | 1/20 [00:07<02:23,  7.56s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:   5%|##5                                               | 1/20 [00:07<02:23,  7.56s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:   5%|##5                                               | 1/20 [00:15<02:23,  7.56s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  10%|#####                                             | 2/20 [00:15<02:16,  7.60s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  10%|#####                                             | 2/20 [00:15<02:16,  7.60s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  10%|#####                                             | 2/20 [00:22<02:16,  7.60s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  15%|#######5                                          | 3/20 [00:22<02:08,  7.55s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  15%|#######5                                          | 3/20 [00:22<02:08,  7.55s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  15%|#######5                                          | 3/20 [00:31<02:08,  7.55s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  20%|##########                                        | 4/20 [00:31<02:07,  7.99s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  20%|##########                                        | 4/20 [00:31<02:07,  7.99s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  20%|##########                                        | 4/20 [00:39<02:07,  7.99s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  25%|############5                                     | 5/20 [00:39<02:00,  8.04s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  25%|############5                                     | 5/20 [00:39<02:00,  8.04s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  25%|############5                                     | 5/20 [00:47<02:00,  8.04s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  30%|###############                                   | 6/20 [00:47<01:51,  7.93s/it]
#
#
#
#
#
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
#
#
#
#
#
#   0%|                                                                                            | 0/7 [00:00<?, ?it/s]
#
#
#
#
# feature_fraction, val_score: inf:   0%|                                                          | 0/7 [00:00<?, ?it/s]
#
#
#
#
# feature_fraction, val_score: 3.426870:   0%|                                                     | 0/7 [00:08<?, ?it/s]
#
#
#
#
# feature_fraction, val_score: 3.426870:  14%|######4                                      | 1/7 [00:08<00:50,  8.38s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  14%|######4                                      | 1/7 [00:08<00:50,  8.38s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  14%|######4                                      | 1/7 [00:15<00:50,  8.38s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  29%|############8                                | 2/7 [00:15<00:40,  8.09s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  29%|############8                                | 2/7 [00:15<00:40,  8.09s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  29%|############8                                | 2/7 [00:22<00:40,  8.09s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  43%|###################2                         | 3/7 [00:22<00:30,  7.67s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  43%|###################2                         | 3/7 [00:22<00:30,  7.67s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  43%|###################2                         | 3/7 [00:29<00:30,  7.67s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  57%|#########################7                   | 4/7 [00:29<00:22,  7.41s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  57%|#########################7                   | 4/7 [00:29<00:22,  7.41s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  57%|#########################7                   | 4/7 [00:36<00:22,  7.41s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  71%|################################1            | 5/7 [00:36<00:14,  7.34s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  71%|################################1            | 5/7 [00:36<00:14,  7.34s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  71%|################################1            | 5/7 [00:44<00:14,  7.34s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  86%|######################################5      | 6/7 [00:44<00:07,  7.41s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  86%|######################################5      | 6/7 [00:44<00:07,  7.41s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  86%|######################################5      | 6/7 [00:51<00:07,  7.41s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870: 100%|#############################################| 7/7 [00:51<00:00,  7.33s/it]
#
#
#
#
#
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#
#
#
#
# num_leaves, val_score: 3.426870:   0%|                                                          | 0/20 [00:00<?, ?it/s]
#
#
#
#
# num_leaves, val_score: 3.426870:   0%|                                                          | 0/20 [00:06<?, ?it/s]
#
#
#
#
# num_leaves, val_score: 3.426870:   5%|##5                                               | 1/20 [00:06<02:07,  6.71s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:   5%|##5                                               | 1/20 [00:06<02:07,  6.71s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:   5%|##5                                               | 1/20 [00:13<02:07,  6.71s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  10%|#####                                             | 2/20 [00:13<02:01,  6.73s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  10%|#####                                             | 2/20 [00:13<02:01,  6.73s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  10%|#####                                             | 2/20 [00:20<02:01,  6.73s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  15%|#######5                                          | 3/20 [00:20<01:54,  6.74s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  15%|#######5                                          | 3/20 [00:20<01:54,  6.74s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  15%|#######5                                          | 3/20 [00:26<01:54,  6.74s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  20%|##########                                        | 4/20 [00:26<01:47,  6.69s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  20%|##########                                        | 4/20 [00:26<01:47,  6.69s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  20%|##########                                        | 4/20 [00:34<01:47,  6.69s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  25%|############5                                     | 5/20 [00:34<01:43,  6.89s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  25%|############5                                     | 5/20 [00:34<01:43,  6.89s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  25%|############5                                     | 5/20 [00:41<01:43,  6.89s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  30%|###############                                   | 6/20 [00:41<01:36,  6.87s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  30%|###############                                   | 6/20 [00:41<01:36,  6.87s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  30%|###############                                   | 6/20 [00:48<01:36,  6.87s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  35%|#################5                                | 7/20 [00:48<01:30,  6.97s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  35%|#################5                                | 7/20 [00:48<01:30,  6.97s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  35%|#################5                                | 7/20 [00:55<01:30,  6.97s/it]
#
#
#
#
# num_leaves, val_score: 3.426870:  40%|####################                              | 8/20 [00:55<01:22,  6.89s/it]
#
#
#
#
#
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
#
#
#
#
#
#   0%|                                                                                            | 0/7 [00:00<?, ?it/s]
#
#
#
#
# feature_fraction, val_score: inf:   0%|                                                          | 0/7 [00:00<?, ?it/s]
#
#
#
#
# feature_fraction, val_score: 1.578833:   0%|                                                     | 0/7 [00:21<?, ?it/s]
#
#
#
#
# feature_fraction, val_score: 1.578833:  14%|######4                                      | 1/7 [00:21<02:09, 21.52s/it]
#
#
#
#
# feature_fraction, val_score: 1.578833:  14%|######4                                      | 1/7 [00:21<02:09, 21.52s/it]
#
#
#
#
# feature_fraction, val_score: 1.578833:  14%|######4                                      | 1/7 [00:43<02:09, 21.52s/it]
#
#
#
#
# feature_fraction, val_score: 1.578833:  29%|############8                                | 2/7 [00:43<01:47, 21.56s/it]
#
#
#
#
# feature_fraction, val_score: 1.578833:  29%|############8                                | 2/7 [00:43<01:47, 21.56s/it]
#
#
#
#
# feature_fraction, val_score: 1.558363:  29%|############8                                | 2/7 [01:03<01:47, 21.56s/it]
#
#
#
#
# feature_fraction, val_score: 1.558363:  43%|###################2                         | 3/7 [01:03<01:24, 21.21s/it]
#
#
#
#
# feature_fraction, val_score: 1.558363:  43%|###################2                         | 3/7 [01:03<01:24, 21.21s/it]
#
#
#
#
# feature_fraction, val_score: 1.558363:  43%|###################2                         | 3/7 [01:25<01:24, 21.21s/it]
#
#
#
#
# feature_fraction, val_score: 1.558363:  57%|#########################7                   | 4/7 [01:25<01:04, 21.49s/it]
#
#
#
#
# feature_fraction, val_score: 1.558363:  57%|#########################7                   | 4/7 [01:25<01:04, 21.49s/it]
#
#
#
#
# feature_fraction, val_score: 1.558363:  57%|#########################7                   | 4/7 [01:47<01:04, 21.49s/it]
#
#
#
#
# feature_fraction, val_score: 1.558363:  71%|################################1            | 5/7 [01:47<00:42, 21.44s/it]
#
#
#
#
#
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
#
#
#
#
#
#   0%|                                                                                            | 0/7 [00:00<?, ?it/s]
#
#
#
#
# feature_fraction, val_score: inf:   0%|                                                          | 0/7 [00:00<?, ?it/s]
#
#
#
#
# feature_fraction, val_score: 1.206830:   0%|                                                     | 0/7 [00:19<?, ?it/s]
#
#
#
#
# feature_fraction, val_score: 1.206830:  14%|######4                                      | 1/7 [00:19<01:55, 19.30s/it]
#
#
#
#
# feature_fraction, val_score: 1.206830:  14%|######4                                      | 1/7 [00:19<01:55, 19.30s/it]
#
#
#
#
# feature_fraction, val_score: 1.155486:  14%|######4                                      | 1/7 [00:36<01:55, 19.30s/it]
#
#
#
#
# feature_fraction, val_score: 1.155486:  29%|############8                                | 2/7 [00:36<01:33, 18.75s/it]
#
#
#
#
# feature_fraction, val_score: 1.155486:  29%|############8                                | 2/7 [00:36<01:33, 18.75s/it]
#
#
#
#
# feature_fraction, val_score: 1.155486:  29%|############8                                | 2/7 [00:59<01:33, 18.75s/it]
#
#
#
#
# feature_fraction, val_score: 1.155486:  43%|###################2                         | 3/7 [00:59<01:19, 19.91s/it]
#
#
#
#
# feature_fraction, val_score: 1.155486:  43%|###################2                         | 3/7 [00:59<01:19, 19.91s/it]
#
#
#
#
# feature_fraction, val_score: 1.155486:  43%|###################2                         | 3/7 [01:17<01:19, 19.91s/it]
#
#
#
#
# feature_fraction, val_score: 1.155486:  57%|#########################7                   | 4/7 [01:17<00:58, 19.47s/it]
#
#
#
#
# feature_fraction, val_score: 1.155486:  57%|#########################7                   | 4/7 [01:17<00:58, 19.47s/it]
#
#
#
#
# feature_fraction, val_score: 1.155486:  57%|#########################7                   | 4/7 [01:42<00:58, 19.47s/it]
#
#
#
#
# feature_fraction, val_score: 1.155486:  71%|################################1            | 5/7 [01:42<00:40, 20.41s/it]
#
#
#
#
#
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
#
#
#
#
#
#   0%|                                                                                            | 0/7 [00:00<?, ?it/s]
#
#
#
#
# feature_fraction, val_score: inf:   0%|                                                          | 0/7 [00:00<?, ?it/s]
#
#
#
#
# feature_fraction, val_score: 4.090770:   0%|                                                     | 0/7 [00:32<?, ?it/s]
#
#
#
#
# feature_fraction, val_score: 4.090770:  14%|######4                                      | 1/7 [00:32<03:12, 32.04s/it]
#
#
#
#
# feature_fraction, val_score: 4.090770:  14%|######4                                      | 1/7 [00:32<03:12, 32.04s/it]
#
#
#
#
# feature_fraction, val_score: 3.382808:  14%|######4                                      | 1/7 [00:57<03:12, 32.04s/it]
#
#
#
#
# feature_fraction, val_score: 3.382808:  29%|############8                                | 2/7 [00:57<02:30, 30.05s/it]
#
#
#
#
# feature_fraction, val_score: 3.382808:  29%|############8                                | 2/7 [00:57<02:30, 30.05s/it]
#
#
#
#
# feature_fraction, val_score: 3.382808:  29%|############8                                | 2/7 [01:28<02:30, 30.05s/it]
#
#
#
#
# feature_fraction, val_score: 3.382808:  43%|###################2                         | 3/7 [01:29<02:02, 30.50s/it]
#
#
#
#
# feature_fraction, val_score: 3.382808:  43%|###################2                         | 3/7 [01:29<02:02, 30.50s/it]
#
#
#
#
# feature_fraction, val_score: 3.382808:  43%|###################2                         | 3/7 [02:01<02:02, 30.50s/it]
#
#
#
#
# feature_fraction, val_score: 3.382808:  57%|#########################7                   | 4/7 [02:01<01:30, 30.31s/it]
#
#
#
#
#
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
#
#
#
#
#
#   0%|                                                                                            | 0/7 [00:00<?, ?it/s]
#
#
#
#
# feature_fraction, val_score: inf:   0%|                                                          | 0/7 [00:00<?, ?it/s]
#
#
#
#
# feature_fraction, val_score: 3.426870:   0%|                                                     | 0/7 [00:24<?, ?it/s]
#
#
#
#
# feature_fraction, val_score: 3.426870:  14%|######4                                      | 1/7 [00:24<02:27, 24.59s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  14%|######4                                      | 1/7 [00:24<02:27, 24.59s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  14%|######4                                      | 1/7 [00:42<02:27, 24.59s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  29%|############8                                | 2/7 [00:42<01:53, 22.68s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  29%|############8                                | 2/7 [00:42<01:53, 22.68s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  29%|############8                                | 2/7 [01:01<01:53, 22.68s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  43%|###################2                         | 3/7 [01:01<01:25, 21.37s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  43%|###################2                         | 3/7 [01:01<01:25, 21.37s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  43%|###################2                         | 3/7 [01:19<01:25, 21.37s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  57%|#########################7                   | 4/7 [01:19<01:01, 20.62s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  57%|#########################7                   | 4/7 [01:20<01:01, 20.62s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  57%|#########################7                   | 4/7 [01:36<01:01, 20.62s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  71%|################################1            | 5/7 [01:36<00:39, 19.54s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  71%|################################1            | 5/7 [01:37<00:39, 19.54s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  71%|################################1            | 5/7 [01:54<00:39, 19.54s/it]
#
#
#
#
# feature_fraction, val_score: 3.426870:  86%|######################################5      | 6/7 [01:54<00:19, 19.08s/it]
#
#
#
#
#
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
#
#
#
#
#
#   0%|                                                                                            | 0/7 [00:00<?, ?it/s]
#
#
#
#
# feature_fraction, val_score: inf:   0%|                                                          | 0/7 [00:00<?, ?it/s]
#
#
#
#
# feature_fraction, val_score: 0.971246:   0%|                                                     | 0/7 [00:41<?, ?it/s]
#
#
#
#
# feature_fraction, val_score: 0.971246:  14%|######4                                      | 1/7 [00:41<04:10, 41.70s/it]
#
#
#
#
# feature_fraction, val_score: 0.971246:  14%|######4                                      | 1/7 [00:41<04:10, 41.70s/it]
#
#
#
#
# feature_fraction, val_score: 0.971246:  14%|######4                                      | 1/7 [01:27<04:10, 41.70s/it]
#
#
#
#
# feature_fraction, val_score: 0.971246:  29%|############8                                | 2/7 [01:27<03:34, 42.90s/it]
#
#
#
#
# feature_fraction, val_score: 0.971246:  29%|############8                                | 2/7 [01:27<03:34, 42.90s/it]
#
#
#
#
# feature_fraction, val_score: 0.958526:  29%|############8                                | 2/7 [02:04<03:34, 42.90s/it]
#
#
#
#
# feature_fraction, val_score: 0.958526:  43%|###################2                         | 3/7 [02:04<02:46, 41.53s/it]
#
#
#
#
#
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
#
#
#
#
#
#   0%|                                                                                            | 0/7 [00:00<?, ?it/s]
#
#
#
#
# feature_fraction, val_score: inf:   0%|                                                          | 0/7 [00:00<?, ?it/s]
#
#
#
#
# feature_fraction, val_score: 1.105765:   0%|                                                     | 0/7 [00:30<?, ?it/s]
#
#
#
#
# feature_fraction, val_score: 1.105765:  14%|######4                                      | 1/7 [00:30<03:01, 30.17s/it]
#
#
#
#
# feature_fraction, val_score: 1.105765:  14%|######4                                      | 1/7 [00:30<03:01, 30.17s/it]
#
#
#
#
# feature_fraction, val_score: 1.099126:  14%|######4                                      | 1/7 [00:59<03:01, 30.17s/it]
#
#
#
#
# feature_fraction, val_score: 1.099126:  29%|############8                                | 2/7 [00:59<02:29, 29.93s/it]
#
#
#
#
# feature_fraction, val_score: 1.099126:  29%|############8                                | 2/7 [00:59<02:29, 29.93s/it]
#
#
#
#
# feature_fraction, val_score: 1.099126:  29%|############8                                | 2/7 [01:27<02:29, 29.93s/it]
#
#
#
#
# feature_fraction, val_score: 1.099126:  43%|###################2                         | 3/7 [01:27<01:57, 29.37s/it]
#
#
#
#
# feature_fraction, val_score: 1.099126:  43%|###################2                         | 3/7 [01:27<01:57, 29.37s/it]
#
#
#
#
# feature_fraction, val_score: 1.070852:  43%|###################2                         | 3/7 [01:57<01:57, 29.37s/it]
#
#
#
#
# feature_fraction, val_score: 1.070852:  57%|#########################7                   | 4/7 [01:57<01:27, 29.32s/it]
#
#
#
#
#
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#
#
#
#
#
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# Number of finished trials: 10
# Best trial:
#   Value: 0.9585259218863685
#   Params:
#     num_leaves: 57
#     learning_rate: 0.07977886530426873
#     subsample: 0.3449928354346119
#     max_bin: 8
#     colsample_bytree: 0.813610248421246
#     reg_alpha: 0.004590131406993605
#     reg_lambda: 16.423746018923037
#     max_depth: 7
# Time:  1104.655316800001

# %%
model = LGBMClassifier(objective='multiclass', metric='multi_logloss', num_class=30, 
                       random_state=10, 
                       num_leaves=57, learning_rate=0.07977886530426873, subsample=0.3449928354346119, max_bin=8,
                       colsample_bytree=0.813610248421246, reg_alpha=0.004590131406993605, reg_lambda=16.423746018923037, max_depth=7)
model.fit(X_train30, y_train30)
y_pred30 = model.predict(X_test30)

balanced_accuracy = balanced_accuracy_score(y_test30, y_pred30)
print(f'The balanced accuracy on testing data from optimized model is {balanced_accuracy}')
# Out:
# The balanced accuracy on testing data from optimized model is 0.711111111111111

# %% [markdown]
# ## Add Pruner for Leaves30
#
# * Optuna pruners andntips: https://optuna.readthedocs.io/en/stable/tutorial/10_key_features/003_efficient_optimization_algorithms.html#pruning-algorithms

# %%
def objective(trial):
    dtrain = lgb.Dataset(X_train30, y_train30)
    upper = min(32768, int(X_train30.shape[0]))
        
    params = {
        "objective": "multiclass",
        "metric": "multi_logloss",
        "num_class": 30, 
        "random_state": 10,
        "verbosity": -1,
        
        # specify the similar search space as FLAML, but optuna has no initial value to suggest
        "num_leaves": trial.suggest_int("num_leaves", 4, upper),
        "learning_rate": trial.suggest_loguniform("learning_rate", 1/1024, 1.0),
        "subsample": trial.suggest_uniform("subsample", 0.1, 1.0),
        "max_bin": trial.suggest_int("max_bin", 3, 10),
        "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.01, 1.0),
        "reg_alpha": trial.suggest_loguniform("reg_alpha", 1/1024, 1024),
        "reg_lambda": trial.suggest_loguniform("reg_lambda", 1/1024, 1024),
        "max_depth": trial.suggest_int("max_depth", 2, 10),
        "extra_trees": True
    }
    
    pruning_callback = optuna.integration.LightGBMPruningCallback(trial, "multi_logloss")
    tuner = lgb.LightGBMTunerCV(
        params, 
        dtrain,
        time_budget=100,
        verbose_eval=False,
        folds=StratifiedKFold(n_splits=5, shuffle=True, random_state=10),
        verbosity=-1,
        callbacks=[pruning_callback]
    )
    
    tuner.run()
    return tuner.best_score

# %%
start = timeit.default_timer()

study = optuna.create_study(direction="minimize", pruner=optuna.pruners.HyperbandPruner())
study.optimize(objective, n_trials=100)

print("Number of finished trials: {}".format(len(study.trials)))
print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
    
stop = timeit.default_timer()
print('Time: ', stop - start)
# Out:
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 1.255608: 100%|#############################################| 7/7 [01:40<00:00, 14.31s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 3.426870: 100%|#############################################| 7/7 [00:59<00:00,  8.54s/it]
# num_leaves, val_score: 3.426870:  30%|###############                                   | 6/20 [00:44<01:43,  7.39s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 3.426870: 100%|#############################################| 7/7 [00:45<00:00,  6.55s/it]
# num_leaves, val_score: 3.426870:  45%|######################5                           | 9/20 [00:59<01:12,  6.61s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 0.953372:  71%|################################1            | 5/7 [02:09<00:51, 25.80s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 3.426870: 100%|#############################################| 7/7 [01:50<00:00, 15.72s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 3.318518:  57%|#########################7                   | 4/7 [01:44<01:18, 26.23s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 6.306932: 100%|#############################################| 7/7 [01:48<00:00, 15.55s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 3.426870: 100%|#############################################| 7/7 [01:48<00:00, 15.50s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 1.079219:  57%|#########################7                   | 4/7 [01:52<01:24, 28.07s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: inf:   0%|                                                          | 0/7 [00:28<?, ?it/s]
# num_leaves, val_score: 1.740782:  20%|##########                                        | 4/20 [01:29<05:58, 22.38s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: inf:   0%|                                                          | 0/7 [00:14<?, ?it/s]
# num_leaves, val_score: 3.426870:  35%|#################5                                | 7/20 [01:26<02:40, 12.35s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: inf:   0%|                                                          | 0/7 [00:13<?, ?it/s]
# num_leaves, val_score: 3.426870:  35%|#################5                                | 7/20 [01:28<02:44, 12.66s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 1.024442:  71%|################################1            | 5/7 [02:02<00:49, 24.58s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: inf:   0%|                                                          | 0/7 [00:14<?, ?it/s]
# num_leaves, val_score: 3.426870:  35%|#################5                                | 7/20 [01:31<02:50, 13.13s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 2.920089:  29%|############8                                | 2/7 [02:03<05:08, 61.65s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 1.379161: 100%|#############################################| 7/7 [01:32<00:00, 13.18s/it]
# num_leaves, val_score: 1.379161:   5%|##5                                               | 1/20 [00:13<04:17, 13.53s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 3.426870:  29%|############8                                | 2/7 [00:39<01:39, 19.97s/it]
# num_leaves, val_score: 3.426870:  25%|############5                                     | 5/20 [01:05<03:17, 13.18s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 3.360900:  57%|#########################7                   | 4/7 [01:49<01:21, 27.32s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 1.209591:  86%|######################################5      | 6/7 [01:54<00:19, 19.14s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: inf:   0%|                                                          | 0/7 [00:24<?, ?it/s]
# num_leaves, val_score: 3.394174:  15%|#######5                                          | 3/20 [01:28<08:19, 29.37s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 0.932875:  71%|################################1            | 5/7 [01:46<00:42, 21.22s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 3.388636:  29%|############8                                | 2/7 [00:25<01:02, 12.57s/it]
# num_leaves, val_score: 3.388636:  45%|######################5                           | 9/20 [01:15<01:32,  8.38s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: inf:   0%|                                                          | 0/7 [00:26<?, ?it/s]
# num_leaves, val_score: 2.120852:  15%|#######5                                          | 3/20 [01:13<06:59, 24.65s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: inf:   0%|                                                          | 0/7 [00:16<?, ?it/s]
# num_leaves, val_score: 2.031874:   5%|##5                                               | 1/20 [01:25<27:03, 85.43s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 1.046274:  57%|#########################7                   | 4/7 [01:42<01:16, 25.64s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 1.974813: 100%|#############################################| 7/7 [01:41<00:00, 14.47s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: inf:   0%|                                                          | 0/7 [00:22<?, ?it/s]
# num_leaves, val_score: 3.046566:  20%|##########                                        | 4/20 [01:22<05:31, 20.75s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: inf:   0%|                                                          | 0/7 [00:09<?, ?it/s]
# num_leaves, val_score: 3.426870:  40%|####################                              | 8/20 [01:38<02:28, 12.36s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 0.948468:  71%|################################1            | 5/7 [01:42<00:41, 20.51s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 3.426870:  14%|######4                                      | 1/7 [00:21<02:06, 21.14s/it]
# num_leaves, val_score: 3.426870:  45%|######################5                           | 9/20 [01:27<01:46,  9.70s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: inf:   0%|                                                          | 0/7 [00:23<?, ?it/s]
# num_leaves, val_score: 1.833494:  15%|#######5                                          | 3/20 [01:35<08:58, 31.68s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 1.076694:  86%|######################################5      | 6/7 [01:51<00:18, 18.66s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 1.132136: 100%|#############################################| 7/7 [01:17<00:00, 11.07s/it]
# num_leaves, val_score: 1.132136:  15%|#######5                                          | 3/20 [00:33<03:10, 11.20s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 3.203419:  86%|######################################5      | 6/7 [01:46<00:17, 17.68s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 1.906735:  43%|###################2                         | 3/7 [01:56<02:35, 38.77s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 1.776024:  71%|################################1            | 5/7 [01:46<00:42, 21.29s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 0.943197:  86%|######################################5      | 6/7 [01:41<00:16, 16.89s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 1.138320:  86%|######################################5      | 6/7 [01:31<00:15, 15.23s/it]
# num_leaves, val_score: 1.138320:   5%|##5                                               | 1/20 [00:12<03:57, 12.51s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 1.215016:  86%|######################################5      | 6/7 [01:19<00:13, 13.27s/it]
# num_leaves, val_score: 1.215016:  10%|#####                                             | 2/20 [00:21<03:14, 10.79s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 3.426870:  14%|######4                                      | 1/7 [00:17<01:46, 17.83s/it]
# num_leaves, val_score: 3.426870:  50%|########################5                        | 10/20 [01:28<01:28,  8.89s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: inf:   0%|                                                          | 0/7 [00:11<?, ?it/s]
# num_leaves, val_score: 3.411979:  55%|##########################9                      | 11/20 [01:38<01:20,  9.00s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 3.426870:  14%|######4                                      | 1/7 [00:17<01:45, 17.55s/it]
# num_leaves, val_score: 3.426870:  50%|########################5                        | 10/20 [01:25<01:25,  8.56s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: inf:   0%|                                                          | 0/7 [00:22<?, ?it/s]
# num_leaves, val_score: 1.475522:  20%|##########                                        | 4/20 [01:20<05:22, 20.18s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: inf:   0%|                                                          | 0/7 [00:23<?, ?it/s]
# num_leaves, val_score: 2.377523:  20%|##########                                        | 4/20 [01:29<05:57, 22.32s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 1.081817: 100%|#############################################| 7/7 [01:40<00:00, 14.40s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
# ...
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: inf:   0%|                                                          | 0/7 [00:44<?, ?it/s]
# num_leaves, val_score: 1.072464:  10%|#####                                             | 2/20 [01:12<10:52, 36.23s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: inf:   0%|                                                          | 0/7 [00:34<?, ?it/s]
# num_leaves, val_score: 1.871499:  10%|#####                                             | 2/20 [01:07<10:11, 33.98s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 1.014590:  57%|#########################7                   | 4/7 [02:07<01:35, 31.89s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 0.908764:  29%|############8                                | 2/7 [01:02<02:35, 31.04s/it]
# num_leaves, val_score: 0.908764:  10%|#####                                             | 2/20 [01:00<09:04, 30.26s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: inf:   0%|                                                          | 0/7 [00:32<?, ?it/s]
# num_leaves, val_score: 1.185070:  20%|##########                                        | 4/20 [01:34<06:17, 23.57s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: inf:   0%|                                                          | 0/7 [00:29<?, ?it/s]
# num_leaves, val_score: 1.700487:  20%|##########                                        | 4/20 [01:30<06:01, 22.59s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 0.919875:  57%|#########################7                   | 4/7 [01:57<01:28, 29.46s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 0.919096:  43%|###################2                         | 3/7 [01:29<01:59, 29.87s/it]
# num_leaves, val_score: 0.918509:   5%|##5                                               | 1/20 [00:27<08:48, 27.83s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 0.901121:  57%|#########################7                   | 4/7 [01:50<01:22, 27.61s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 0.954826:  43%|###################2                         | 3/7 [01:33<02:04, 31.00s/it]
# num_leaves, val_score: 0.954826:   5%|##5                                               | 1/20 [00:28<09:02, 28.57s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 0.902942:  14%|######4                                      | 1/7 [00:34<03:27, 34.62s/it]
# num_leaves, val_score: 0.902942:  15%|#######5                                          | 3/20 [01:20<07:34, 26.72s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 0.969406:  14%|######4                                      | 1/7 [00:40<04:01, 40.28s/it]
# num_leaves, val_score: 0.969406:  15%|#######5                                          | 3/20 [01:03<05:57, 21.02s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 0.910548:  57%|#########################7                   | 4/7 [02:01<01:31, 30.45s/it]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# C:\Users\wuhan\anaconda3\lib\site-packages\optuna\integration\_lightgbm_tuner\optimize.py:445: FutureWarning: `verbosity` argument is deprecated and will be removed in the future. The removal of this feature is currently scheduled for v4.0.0, but this schedule is subject to change. Please use optuna.logging.set_verbosity() instead.
#   FutureWarning,
# feature_fraction, val_score: 0.971763:  29%|############8                                | 2/7 [01:12<03:00, 36.19s/it]
# num_leaves, val_score: 0.971763:   5%|##5                                               | 1/20 [00:28<09:01, 28.53s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# Number of finished trials: 100
# Best trial:
#   Value: 0.9011210615816487
#   Params:
#     num_leaves: 132
#     learning_rate: 0.01450911890294548
#     subsample: 0.6602135782504309
#     max_bin: 9
#     colsample_bytree: 0.7259319761026826
#     reg_alpha: 0.0012697671364013724
#     reg_lambda: 0.1981004944741745
#     max_depth: 2
# Time:  11033.8225253

# %%
model = LGBMClassifier(objective='multiclass', metric='multi_logloss', num_class=132, 
                       random_state=10, 
                       num_leaves=270, learning_rate=0.01450911890294548, subsample=0.6602135782504309, max_bin=9,
                       colsample_bytree=0.7259319761026826, reg_alpha=0.0012697671364013724, reg_lambda=0.1981004944741745, max_depth=2)
model.fit(X_train30, y_train30)
y_pred30 = model.predict(X_test30)

balanced_accuracy = balanced_accuracy_score(y_test30, y_pred30)
print(f'The balanced accuracy on testing data from optimized model is {balanced_accuracy}')
# Out:
# The balanced accuracy on testing data from optimized model is 0.6166666666666667
