# %% [markdown]
# Licensed under the MIT License.
#
# Copyright (c) 2025-2035. All rights reserved by Hanhan Wu.
#
# Permission is hereby granted to view this code for evaluation purposes only.
# You may not reuse, copy, modify, merge, publish, distribute, sublicense,
# or exploit this code without Hanhan Wu's EXPLICIT written permission.
#
#
# # Performance Comparison with Bigger Finance Q&A Data
#
# * Dataset
#   * 100 training records
#   * 180 validation records
#   * 200 testing records
# * Standardized way to compare the performance
#   * Baseline vs DsPy vs Adalflow
#   * Same initial prompt, save testset

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import dspy
from concurrent.futures import ThreadPoolExecutor, as_completed

from utils import *

import warnings
warnings.filterwarnings('ignore')


model_str = 'gpt-4.1-nano'

# %% [markdown]
# ### Load Testset

# %%
# testet format for baseline and Adalflow
test_df = pd.read_parquet('final_finance_qa_test.parquet').drop_duplicates(subset=['question', 'ground_truth'])
print(test_df.shape)
display(test_df.head())

# testet format for Dspy
dspy_testset = [
    dspy.Example({
        "question": record['question'],
        "context": list(record['context']),
        "ground_truth": record['ground_truth']
        }).with_inputs('question', 'context')
    for record in test_df.to_dict(orient='records')
]
print(len(dspy_testset))
print(dspy_testset[0])
# Out:
# (197, 4)
#       doc_id                                            context  \
# 0  9808.jpeg  [### Document Type\nThe document is an invoice...
# 1  7461.jpeg  [### Document Type:\nThis is a Print Productio...
# 2  5471.jpeg  [### Document Type\nThe document is a financia...
# 3  7440.jpeg  [### Document Type\nThis is a financial estima...
# 4  2613.jpeg  [### Document Type\nThe image shows a financia...
#
#                                             question  \
# 0          What is the invoice date of the document?
# 1  What is the client's name mentioned in the Pri...
# 2                  Who is the issuer of the invoice?
# 3  What is the name of the company that created t...
# 4                   What is the issuer of the check?
#
#                                         ground_truth
# 0             The invoice date is December 22, 1993.
# 1            The client's name is Philip Morris Inc.
# 2                        Borrison Laboratories, Inc.
# 3  Leo Burnett U.S.A., a division of Leo Burnett ...
# 4                             The Tobacco Institute.
# 197
# Example({'question': 'What is the invoice date of the document?', 'context': ["### Document Type\nThe document is an invoice from Fannon-Luers Associates Inc., a company that offers data processing, mailing, and fulfillment services.\n\n### Key Details\n- **Invoice Date:** December 22, 1993\n- **Invoice Number:** 25737\n- **Customer ID:** 108\n- **Company Address:** Tobacco Institute, 1875 I Street NW, 8th Floor, Washington, D.C. 20006\n- **Supplier's Address and Contact:** Fannon-Luers Associates Inc., 5352 - 46th Ave., Hyattsville, MD 20781; Phone: (301) 864-3776\n- **Page Number of Invoice:** 6\n- **Payment Terms:** Net 30\n- **Description and Amounts:**\n  - THYSN: Youth Requests - $1152.20\n    - Tasks: Process Mail, Data Entry, Merge Tape and Prepare Labels.\n    - Volume: 2000\n  - Postage and Mail (Matériel for third class) - $201.20\n  - General Postage Used - $466.00\n- **Total Amount Due:** $1819.20\n- **Sales Tax:** $0.00\n\n### Insights and Observations\n- **Vendor Services and Pricing:** The invoice details charges mainly centered on processing, data management, and postage services. The charges are likely based on the volume of work and postage utilized.\n- **Zero Sales Tax:** The invoice reflects zero sales tax, which might indicate either an exemption or a non-taxable service according to the state laws.\n- **Total Amount Consideration:** The combined cost of processing/data entry and postage constitute the bulk of the charges, suggesting significant mailing activity.\n- **Historical Context:** Considering the invoice date, this document serves as a financial historical record from over two decades ago, emphasizing past billing practices and service rates which could be compared to current costs for similar services.\n\nThis detailed itemization and context can be useful for financial analysis, historical accounting comparisons, and understanding client-vendor transactions from the specified period."], 'ground_truth': 'The invoice date is December 22, 1993.'}) (input_keys={'context', 'question'})

# %% [markdown]
# ### Generate Answers

# %%
baseline_prompt = """Answer questions with short factoid answers. 
                    You will receive context(contain relevant facts). 
                    Think step by step."""

adalflow_prompt = """Answer questions with short factoid answers. 
                    You will receive context (contain relevant facts). Think step by step. 
                    Focus on extracting the most relevant factoid directly answering the question. 
                    Do not include explanations or additional commentary. 
                    Ensure the answer is concise, accurate, and based solely on the provided context."""

dspy_optimized_progfram = dspy.load("dspy_compiled_rag/")

# %%
def process_row(row):
    context = "\n".join(row['context']) if isinstance(row['context'], (list, tuple)) else str(row['context'])
    question = row['question']
    ground_truth = row['ground_truth']
    baseline_answer = get_gpt_answer(baseline_prompt, question, context, model=model_str)
    adalflow_answer = get_gpt_answer(adalflow_prompt, question, context, model=model_str)
    return {
        "question": question,
        "context": context,
        "ground_truth": ground_truth,
        "baseline_answer": baseline_answer,
        "adalflow_answer": adalflow_answer,
    }

results = []
with ThreadPoolExecutor(max_workers=8) as executor:
    futures = [executor.submit(process_row, row) for _, row in test_df.iterrows()]
    for future in as_completed(futures):
        results.append(future.result())

results_df = pd.DataFrame(results)
print(results_df.shape)
display(results_df.head())
# Out:
# (197, 5)
#                                             question  \
# 0                   What is the company's RIDE Code?
# 1        What is the date of the check request form?
# 2  What is the state covered in the State Contrib...
# 3  What is the client's name mentioned in the Pri...
# 4                  Who is the issuer of the invoice?
#
#                                              context  \
# 0  ['### Document Type\nThe image shows a financi...
# 1  ['### Document Type:\nCheck Request Form\n\n##...
# 2  ['### Document Type\nThis is a "State Contribu...
# 3  ['### Document Type:\nThis is a Print Producti...
# 4  ['### Document Type\nThe document is a financi...
#
#                                         ground_truth  \
# 0                 The company's RIDE Code is 471120.
# 1  The date of the check request form is April 20...
# 2                     The state covered is New York.
# 3            The client's name is Philip Morris Inc.
# 4                        Borrison Laboratories, Inc.
#
#                baseline_answer              adalflow_answer
# 0                       471120                       471120
# 1               April 20, 1993               April 20, 1993
# 2                     New York                     New York
# 3           Philip Morris Inc.           Philip Morris Inc.
# 4  Borrison Laboratories, Inc.  Borrison Laboratories, Inc.

# %%
llm = dspy.LM(f"openai/{model_str}")
dspy.settings.configure(lm=llm)

dspy_results = []
for r in dspy_testset:
    pred = dspy_optimized_progfram(question=r.question, context=r.context)
    dspy_results.append({
        "question": r.question,
        "ground_truth": r.ground_truth,
        "dspy_answer": pred.answer
    })

dspy_results_df = pd.DataFrame(dspy_results)
print(dspy_results_df.shape)
dspy_results_df.head()
# Out:
# (197, 3)
#                                             question  \
# 0          What is the invoice date of the document?
# 1  What is the client's name mentioned in the Pri...
# 2                  Who is the issuer of the invoice?
# 3  What is the name of the company that created t...
# 4                   What is the issuer of the check?
#
#                                         ground_truth  \
# 0             The invoice date is December 22, 1993.
# 1            The client's name is Philip Morris Inc.
# 2                        Borrison Laboratories, Inc.
# 3  Leo Burnett U.S.A., a division of Leo Burnett ...
# 4                             The Tobacco Institute.
#
#                    dspy_answer
# 0            December 22, 1993
# 1           Philip Morris Inc.
# 2  Borrison Laboratories, Inc.
# 3           Leo Burnett U.S.A.
# 4        The Tobacco Institute

# %%
all_answer_df = results_df.merge(dspy_results_df, on=['question', 'ground_truth'], how='inner')
print(all_answer_df.shape)

all_answer_df.head()
# Out:
# (197, 6)
#                                             question  \
# 0                   What is the company's RIDE Code?
# 1        What is the date of the check request form?
# 2  What is the state covered in the State Contrib...
# 3  What is the client's name mentioned in the Pri...
# 4                  Who is the issuer of the invoice?
#
#                                              context  \
# 0  ['### Document Type\nThe image shows a financi...
# 1  ['### Document Type:\nCheck Request Form\n\n##...
# 2  ['### Document Type\nThis is a "State Contribu...
# 3  ['### Document Type:\nThis is a Print Producti...
# 4  ['### Document Type\nThe document is a financi...
#
#                                         ground_truth  \
# 0                 The company's RIDE Code is 471120.
# 1  The date of the check request form is April 20...
# 2                     The state covered is New York.
# 3            The client's name is Philip Morris Inc.
# 4                        Borrison Laboratories, Inc.
#
#                baseline_answer              adalflow_answer  \
# 0                       471120                       471120
# 1               April 20, 1993               April 20, 1993
# 2                     New York                     New York
# 3           Philip Morris Inc.           Philip Morris Inc.
# 4  Borrison Laboratories, Inc.  Borrison Laboratories, Inc.
#
#                    dspy_answer
# 0                       471120
# 1               April 20, 1993
# 2                     New York
# 3           Philip Morris Inc.
# 4  Borrison Laboratories, Inc.

# %%
def process_record(record):
    evals = {}
    for answer_type in ['baseline_answer', 'adalflow_answer', 'dspy_answer']:
        answer = record.get(answer_type)
        if answer is not None:
            eval_score, eval_reason = my_deepeval_answer_correctness(
                record['question'],
                list(record['context']),
                record['ground_truth'],
                answer
            )
            evals[f'{answer_type}_score'] = eval_score
            evals[f'{answer_type}_reason'] = eval_reason
        else:
            evals[f'{answer_type}_score'] = None
            evals[f'{answer_type}_reason'] = None
    return {**record, **evals}

final_eval_lst = []
with ThreadPoolExecutor(max_workers=8) as executor:
    futures = [executor.submit(process_record, record) for record in all_answer_df.to_dict(orient='records')]
    for future in as_completed(futures):
        final_eval_lst.append(future.result())

# %%
final_eval_df = pd.DataFrame(final_eval_lst)
print(final_eval_df.shape)
display(final_eval_df.head())
# Out:
# (197, 12)
#                                             question  \
# 0                  Who is the issuer of the invoice?
# 1  What is the name of the company that created t...
# 2        What is the date of the check request form?
# 3                              Who issued the check?
# 4                   What is the company's RIDE Code?
#
#                                              context  \
# 0  ['### Document Type\nThe document is a financi...
# 1  ['### Document Type\nThis is a financial estim...
# 2  ['### Document Type:\nCheck Request Form\n\n##...
# 3  ['### Document Type:\nThis image depicts a fin...
# 4  ['### Document Type\nThe image shows a financi...
#
#                                         ground_truth  \
# 0                        Borrison Laboratories, Inc.
# 1  Leo Burnett U.S.A., a division of Leo Burnett ...
# 2  The date of the check request form is April 20...
# 3                              The Tobacco Institute
# 4                 The company's RIDE Code is 471120.
#
#                baseline_answer              adalflow_answer  \
# 0  Borrison Laboratories, Inc.  Borrison Laboratories, Inc.
# 1           Leo Burnett U.S.A.           Leo Burnett U.S.A.
# 2               April 20, 1993               April 20, 1993
# 3        The Tobacco Institute        The Tobacco Institute
# 4                       471120                       471120
#
#                    dspy_answer  baseline_answer_score  \
# 0  Borrison Laboratories, Inc.               0.336861
# 1           Leo Burnett U.S.A.               0.297927
# 2               April 20, 1993               0.608321
# 3        The Tobacco Institute               1.000000
# 4                       471120               0.170318
#
#                               baseline_answer_reason  adalflow_answer_score  \
# 0  Actual output matches the Expected Output exac...               0.960910
# 1  Actual Output omits the 'a division of Leo Bur...               0.374572
# 2  The Actual Output 'April 20, 1993' matches the...               0.494986
# 3  The Actual Output matches the Expected Output ...               0.987457
# 4  Actual output '471120' matches the numerical p...               0.342266
#
#                               adalflow_answer_reason  dspy_answer_score  \
# 0  The Actual Output matches the Expected Output ...           1.000000
# 1  Actual Output only states 'Leo Burnett U.S.A.'...           0.284023
# 2  The Actual Output 'April 20, 1993' omits the p...           0.636574
# 3  The Actual Output matches the Expected Output ...           1.000000
# 4  The Actual Output '471120' matches the numeric...           0.452535
#
#                                   dspy_answer_reason
# 0  The Actual Output matches the Expected Output ...
# 1  Actual Output omits the detailed division and ...
# 2  The Actual Output correctly identifies the dat...
# 3  Actual Output matches Expected Output exactly,...
# 4  The Actual Output '471120' omits the required ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))

# Kernel density plots
sns.kdeplot(
    final_eval_df['baseline_answer_score'].dropna(),
    color='orange',
    label=f'Baseline (avg={final_eval_df["baseline_answer_score"].mean():.2f})'
)
sns.kdeplot(
    final_eval_df['adalflow_answer_score'].dropna(),
    color='green',
    label=f'Adalflow (avg={final_eval_df["adalflow_answer_score"].mean():.2f})'
)
sns.kdeplot(
    final_eval_df['dspy_answer_score'].dropna(),
    color='purple',
    label=f'DsPy (avg={final_eval_df["dspy_answer_score"].mean():.2f})'
)

plt.xlabel('Score')
plt.ylabel('Density')
plt.title('Kernel Density Plot of Answer Correctness Scores')
plt.legend()
plt.grid(True)
plt.show()
