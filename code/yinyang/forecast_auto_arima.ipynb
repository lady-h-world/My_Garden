# %% [markdown]
# Licensed under the MIT License.
#
# Copyright (c) 2021-2031. All rights reserved.
#
# # Time Series Forecasting - Auto ARIMA
#
# * Python Auto ARIMA: https://alkaline-ml.com/pmdarima/modules/generated/pmdarima.arima.auto_arima.html

# %%
import pandas as pd
import pmdarima as pm
import matplotlib.pyplot as plt
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_absolute_percentage_error as mape, r2_score

import warnings
warnings.filterwarnings("ignore")

# %%
ts_df = pd.read_pickle('../crystal_ball/data_collector/structured_data/sales_ts.pkl')
print(ts_df.shape)

ts_df_train = ts_df.iloc[ts_df.index < '2015-03-01']
ts_df_test = ts_df.iloc[ts_df.index >= '2015-03-01']
print(ts_df_train.shape, ts_df_test.shape)

ts_df_train.head()
# Out:
# (942, 1)
# (789, 1) (153, 1)
#             Daily_Sales
# Date
# 2013-01-01        58165
# 2013-01-02      4822042
# 2013-01-03      4415571
# 2013-01-04      4587035
# 2013-01-05      4078281

# %%
def auto_arima_forecast(train_ts, test_ts, fitted_model, title):
    """
    Forecast and plot the train, test & forecasted time series.
    
    @param train_ts: the training time series data
    @param test_ts: the testing time series data
    @param fitted_model: the trained model
    @param title: the title of the plot
    @return: return the forecast performance results
    """
    y_pred = fitted_model.predict(len(test_ts))
    
    pred_mape = mape(test_ts, y_pred)
    pred_r2 = r2_score(test_ts, y_pred)
    
    plt.figure(figsize=(20,7))
    plt.plot(train_ts.index, train_ts, label='Train')
    plt.plot(test_ts.index, test_ts, label='Test')
    plt.plot(test_ts.index, y_pred, label='Forecast')
    plt.legend(loc='best')
    plt.title(f'{title} (MAPE: {pred_mape}, R2: {pred_r2})')
    plt.show()
    
    return pred_mape, pred_r2

# %% [markdown]
# ### Forecast with Auto ARIMA
#
# #### With Seasonal Settings

# %%
autoarima_model_s = pm.auto_arima(ts_df_train, 
                    start_p=1, start_q=1,
                    test='adf',  # use ADF test to find optimal 'd'
                    max_p=10, max_q=3,  # maximum p and q
                    m=7,  # the period for seasonal differencing
                    d=None,  # let model determine 'd'
                    seasonal=True,
                    start_P=0,
                    D=0,
                    trace=True,
                    error_action='ignore',
                    suppress_warnings=True,
                    stepwise=True)
print(autoarima_model_s.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,1)[7] intercept   : AIC=25102.365, Time=0.62 sec
#  ARIMA(0,0,0)(0,0,0)[7] intercept   : AIC=25227.957, Time=0.07 sec
#  ARIMA(1,0,0)(1,0,0)[7] intercept   : AIC=25137.276, Time=0.83 sec
#  ARIMA(0,0,1)(0,0,1)[7] intercept   : AIC=25100.261, Time=0.35 sec
#  ARIMA(0,0,0)(0,0,0)[7]             : AIC=26488.905, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[7] intercept   : AIC=25229.758, Time=0.22 sec
#  ARIMA(0,0,1)(1,0,1)[7] intercept   : AIC=25091.450, Time=2.04 sec
#  ARIMA(0,0,1)(1,0,0)[7] intercept   : AIC=25173.901, Time=0.86 sec
#  ARIMA(0,0,1)(2,0,1)[7] intercept   : AIC=24913.067, Time=3.40 sec
#  ARIMA(0,0,1)(2,0,0)[7] intercept   : AIC=25133.858, Time=2.76 sec
#  ARIMA(0,0,1)(2,0,2)[7] intercept   : AIC=24905.038, Time=5.06 sec
#  ARIMA(0,0,1)(1,0,2)[7] intercept   : AIC=24936.616, Time=3.40 sec
#  ARIMA(0,0,0)(2,0,2)[7] intercept   : AIC=24910.672, Time=4.37 sec
#  ARIMA(1,0,1)(2,0,2)[7] intercept   : AIC=inf, Time=8.69 sec
#  ARIMA(0,0,2)(2,0,2)[7] intercept   : AIC=24899.773, Time=9.62 sec
#  ARIMA(0,0,2)(1,0,2)[7] intercept   : AIC=24933.482, Time=5.81 sec
#  ARIMA(0,0,2)(2,0,1)[7] intercept   : AIC=24908.005, Time=3.06 sec
#  ARIMA(0,0,2)(1,0,1)[7] intercept   : AIC=25089.415, Time=2.56 sec
#  ARIMA(1,0,2)(2,0,2)[7] intercept   : AIC=inf, Time=7.71 sec
#  ARIMA(0,0,3)(2,0,2)[7] intercept   : AIC=24885.301, Time=6.94 sec
#  ARIMA(0,0,3)(1,0,2)[7] intercept   : AIC=24922.040, Time=4.12 sec
#  ARIMA(0,0,3)(2,0,1)[7] intercept   : AIC=24890.306, Time=2.95 sec
#  ARIMA(0,0,3)(1,0,1)[7] intercept   : AIC=25061.294, Time=2.53 sec
#  ARIMA(1,0,3)(2,0,2)[7] intercept   : AIC=inf, Time=8.23 sec
#  ARIMA(0,0,3)(2,0,2)[7]             : AIC=25757.622, Time=3.69 sec
#
# Best model:  ARIMA(0,0,3)(2,0,2)[7] intercept
# Total fit time: 89.981 seconds
#                                        SARIMAX Results
# ==============================================================================================
# Dep. Variable:                                      y   No. Observations:                  789
# Model:             SARIMAX(0, 0, 3)x(2, 0, [1, 2], 7)   Log Likelihood              -12433.651
# Date:                                Sun, 17 Jul 2022   AIC                          24885.301
# Time:                                        18:52:15   BIC                          24927.338
# Sample:                                             0   HQIC                         24901.460
#                                                 - 789
# Covariance Type:                                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   4.205e+06   6.08e+05      6.917      0.000    3.01e+06     5.4e+06
# ma.L1          0.1612      0.048      3.387      0.001       0.068       0.255
# ma.L2          0.1815      0.069      2.644      0.008       0.047       0.316
# ma.L3          0.2248      0.050      4.526      0.000       0.127       0.322
# ar.S.L7       -0.2461      0.095     -2.585      0.010      -0.433      -0.060
# ar.S.L14       0.4323      0.099      4.353      0.000       0.238       0.627
# ma.S.L7        0.6476      0.098      6.628      0.000       0.456       0.839
# ma.S.L14       0.1545      0.111      1.394      0.163      -0.063       0.372
# sigma2      4.479e+12      0.111   4.04e+13      0.000    4.48e+12    4.48e+12
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.65   Jarque-Bera (JB):               127.62
# Prob(Q):                              0.42   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.84   Skew:                            -0.28
# Prob(H) (two-sided):                  0.17   Kurtosis:                         4.89
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.21e+29. Standard errors may be unstable.

# %%
autoarima_model_s.plot_diagnostics(figsize=(15,10))
plt.show()

# %%
pred_mape_autoarima_s, pred_r2_autoarima_s = auto_arima_forecast(ts_df_train, ts_df_test, autoarima_model_s, title=f"Forecast using AUTO ARIMA Seasonal {autoarima_model_s.order}")

# %% [markdown]
# #### Without Seasonal Settings

# %%
autoarima_model = pm.auto_arima(ts_df_train, 
                    start_p=1, start_q=1,
                    test='adf',  # use ADF test to find optimal 'd'
                    max_p=10, max_q=3,  # maximum p and q
                    m=1,  # the period for seasonal differencing
                    d=None,  # let model determine 'd'
                    seasonal=False,
                    start_P=0,
                    D=0,
                    trace=True,
                    error_action='ignore',
                    suppress_warnings=True,
                    stepwise=True)
print(autoarima_model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.30 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=26488.905, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=25700.780, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=26165.558, Time=0.05 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=25561.664, Time=0.05 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=25450.916, Time=0.12 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=25417.178, Time=0.15 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=25416.099, Time=0.17 sec
#  ARIMA(6,0,0)(0,0,0)[0]             : AIC=25412.271, Time=0.28 sec
#  ARIMA(7,0,0)(0,0,0)[0]             : AIC=inf, Time=0.64 sec
#  ARIMA(6,0,1)(0,0,0)[0]             : AIC=25233.087, Time=1.93 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=inf, Time=1.46 sec
#  ARIMA(7,0,1)(0,0,0)[0]             : AIC=24880.215, Time=1.01 sec
#  ARIMA(8,0,1)(0,0,0)[0]             : AIC=24858.967, Time=1.45 sec
#  ARIMA(8,0,0)(0,0,0)[0]             : AIC=inf, Time=0.63 sec
#  ARIMA(9,0,1)(0,0,0)[0]             : AIC=24853.407, Time=1.56 sec
#  ARIMA(9,0,0)(0,0,0)[0]             : AIC=inf, Time=0.55 sec
#  ARIMA(10,0,1)(0,0,0)[0]             : AIC=24728.898, Time=2.99 sec
#  ARIMA(10,0,0)(0,0,0)[0]             : AIC=inf, Time=0.93 sec
#  ARIMA(10,0,2)(0,0,0)[0]             : AIC=24760.930, Time=4.35 sec
#  ARIMA(9,0,2)(0,0,0)[0]             : AIC=24792.053, Time=3.48 sec
#  ARIMA(10,0,1)(0,0,0)[0] intercept   : AIC=24686.996, Time=3.13 sec
#  ARIMA(9,0,1)(0,0,0)[0] intercept   : AIC=24696.404, Time=3.92 sec
#  ARIMA(10,0,0)(0,0,0)[0] intercept   : AIC=24685.788, Time=1.78 sec
#  ARIMA(9,0,0)(0,0,0)[0] intercept   : AIC=24699.568, Time=1.71 sec
#
# Best model:  ARIMA(10,0,0)(0,0,0)[0] intercept
# Total fit time: 32.700 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  789
# Model:              SARIMAX(10, 0, 0)   Log Likelihood              -12330.894
# Date:                Sun, 17 Jul 2022   AIC                          24685.788
# Time:                        18:54:51   BIC                          24741.837
# Sample:                             0   HQIC                         24707.333
#                                 - 789
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   5.544e+06   1.69e-09   3.29e+15      0.000    5.54e+06    5.54e+06
# ar.L1          0.1165      0.026      4.541      0.000       0.066       0.167
# ar.L2          0.1021      0.034      3.022      0.003       0.036       0.168
# ar.L3          0.0410      0.028      1.475      0.140      -0.013       0.095
# ar.L4         -0.1562      0.021     -7.474      0.000      -0.197      -0.115
# ar.L5         -0.1742      0.024     -7.158      0.000      -0.222      -0.126
# ar.L6         -0.1770      0.029     -6.169      0.000      -0.233      -0.121
# ar.L7          0.5832      0.022     26.824      0.000       0.541       0.626
# ar.L8         -0.2505      0.028     -8.900      0.000      -0.306      -0.195
# ar.L9         -0.2612      0.034     -7.638      0.000      -0.328      -0.194
# ar.L10        -0.1403      0.027     -5.167      0.000      -0.194      -0.087
# sigma2      2.161e+12   5.79e-15   3.74e+26      0.000    2.16e+12    2.16e+12
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.18   Jarque-Bera (JB):               236.03
# Prob(Q):                              0.67   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.79   Skew:                             0.16
# Prob(H) (two-sided):                  0.05   Kurtosis:                         5.66
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.35e+41. Standard errors may be unstable.

# %%
autoarima_model.plot_diagnostics(figsize=(15,10))
plt.show()

# %%
pred_mape_autoarima, pred_r2_autoarima = auto_arima_forecast(ts_df_train, ts_df_test, autoarima_model, title=f"Forecast using AUTO ARIMA non-Seasonal {autoarima_model_s.order}")
