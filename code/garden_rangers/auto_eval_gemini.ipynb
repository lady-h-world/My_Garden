# %% [markdown]
# Licensed under the MIT License.
#
# Copyright (c) 2025-2035. All rights reserved by Hanhan Wu.
#
# Permission is hereby granted to view this code for evaluation purposes only.
# You may not reuse, copy, modify, merge, publish, distribute, sublicense,
# or exploit this code without Hanhan Wu's EXPLICIT written permission.
#
# # Auto Eval with Gemini

# %%
# %load_ext autoreload
# %autoreload 2

from datasets import load_dataset
import pandas as pd
import yaml
import nest_asyncio
nest_asyncio.apply()

from utils import *

import warnings
warnings.filterwarnings('ignore')


with open('prompt_versions.yaml', 'r') as file:
    prompt_versions = yaml.safe_load(file)
    
llm_model_str = 'gemini-2.5-flash-lite'

# %%
fiqa_eval = load_dataset("explodinggradients/fiqa", "ragas_eval")['baseline']

rag_lst = []
for record in fiqa_eval:
    rag_lst.append({
        'query': record['question'],
        'retrieved_content': record['contexts'],
        'referenced_answer': record['ground_truths'][0],
        'answer': record['answer'].strip()
    })

rag_df = pd.DataFrame(rag_lst)
print(rag_df.shape)
rag_df.head()
# Out:
# (30, 4)
#                                                query  \
# 0  How to deposit a cheque issued to an associate...
# 1  Can I send a money order from USPS as a business?
# 2  1 EIN doing business under multiple business n...
# 3         Applying for and receiving business credit
# 4               401k Transfer After Business Closure
#
#                                    retrieved_content  \
# 0  [Just have the associate sign the back and the...
# 1  [Sure you can.  You can fill in whatever you w...
# 2  [You're confusing a lot of things here. Compan...
# 3  [Set up a meeting with the bank that handles y...
# 4  [The time horizon for your 401K/IRA is essenti...
#
#                                    referenced_answer  \
# 0  Have the check reissued to the proper payee.Ju...
# 1  Sure you can.  You can fill in whatever you wa...
# 2  You're confusing a lot of things here. Company...
# 3  "I'm afraid the great myth of limited liabilit...
# 4  You should probably consult an attorney. Howev...
#
#                                               answer
# 0  The best way to deposit a cheque issued to an ...
# 1  Yes, you can send a money order from USPS as a...
# 2  Yes, it is possible to have one EIN doing busi...
# 3  Applying for and receiving business credit can...
# 4  If your employer has closed and you need to tr...

# %%
rr_df = asyncio.run(get_retrieval_relevancy_output_async(rag_df, llm_model_str,
                                                        prompt_versions['rr_prompt_template']))

# %%
print(rr_df.shape)

rr_df.head()
# Out:
# (30, 6)
#                                                query  \
# 0  How to deposit a cheque issued to an associate...
# 1  Can I send a money order from USPS as a business?
# 2  1 EIN doing business under multiple business n...
# 3         Applying for and receiving business credit
# 4               401k Transfer After Business Closure
#
#                                    retrieved_content  \
# 0  [Just have the associate sign the back and the...
# 1  [Sure you can.  You can fill in whatever you w...
# 2  [You're confusing a lot of things here. Compan...
# 3  [Set up a meeting with the bank that handles y...
# 4  [The time horizon for your 401K/IRA is essenti...
#
#                                    referenced_answer  \
# 0  Have the check reissued to the proper payee.Ju...
# 1  Sure you can.  You can fill in whatever you wa...
# 2  You're confusing a lot of things here. Company...
# 3  "I'm afraid the great myth of limited liabilit...
# 4  You should probably consult an attorney. Howev...
#
#                                               answer  rr_auto_score  \
# 0  The best way to deposit a cheque issued to an ...              3
# 1  Yes, you can send a money order from USPS as a...              3
# 2  Yes, it is possible to have one EIN doing busi...              2
# 3  Applying for and receiving business credit can...              3
# 4  If your employer has closed and you need to tr...              3
#
#                                         rr_reasoning
# 0  The retrieved content directly addresses the u...
# 1  The retrieved content directly answers the use...
# 2  The retrieved content mentions 'Doing Business...
# 3  The retrieved content provides detailed steps ...
# 4  The retrieved content directly addresses the u...

# %%
final_df = asyncio.run(get_answer_usefulness_output_async(rr_df, llm_model_str,
                                                        prompt_versions['au_prompt_template']))

# %%
print(final_df.shape)

final_df.head()
# Out:
# (30, 8)
#                                                query  \
# 0  How to deposit a cheque issued to an associate...
# 1  Can I send a money order from USPS as a business?
# 2  1 EIN doing business under multiple business n...
# 3         Applying for and receiving business credit
# 4               401k Transfer After Business Closure
#
#                                    retrieved_content  \
# 0  [Just have the associate sign the back and the...
# 1  [Sure you can.  You can fill in whatever you w...
# 2  [You're confusing a lot of things here. Compan...
# 3  [Set up a meeting with the bank that handles y...
# 4  [The time horizon for your 401K/IRA is essenti...
#
#                                    referenced_answer  \
# 0  Have the check reissued to the proper payee.Ju...
# 1  Sure you can.  You can fill in whatever you wa...
# 2  You're confusing a lot of things here. Company...
# 3  "I'm afraid the great myth of limited liabilit...
# 4  You should probably consult an attorney. Howev...
#
#                                               answer  rr_auto_score  \
# 0  The best way to deposit a cheque issued to an ...              3
# 1  Yes, you can send a money order from USPS as a...              3
# 2  Yes, it is possible to have one EIN doing busi...              2
# 3  Applying for and receiving business credit can...              3
# 4  If your employer has closed and you need to tr...              3
#
#                                         rr_reasoning  answer_usefulness_score  \
# 0  The retrieved content directly addresses the u...                      0.6
# 1  The retrieved content directly answers the use...                      1.0
# 2  The retrieved content mentions 'Doing Business...                      0.2
# 3  The retrieved content provides detailed steps ...                      0.8
# 4  The retrieved content directly addresses the u...                      0.4
#
#                                         au_reasoning
# 0  The AI's answer provides a generally correct m...
# 1  The AI's answer is exceptionally helpful, rele...
# 2  The AI's answer is factually incorrect and mis...
# 3  The AI's answer is helpful and relevant to the...
# 4  The AI's answer provides general advice on tra...
