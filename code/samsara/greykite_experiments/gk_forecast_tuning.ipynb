# %% [markdown]
# Licensed under the MIT License.
#
# Copyright (c) 2021-2031. All rights reserved.
#
# # Greykite Forecast Components Config and Grid Search
#
# * Greykite model components include seasonality, changepoints, events, etc.: https://linkedin.github.io/greykite/docs/0.1.0/html/pages/model_components/0100_introduction.html#model-components
#   * Seasonality config: https://linkedin.github.io/greykite/docs/0.1.0/html/pages/model_components/0300_seasonality.html
#   * Events config: https://linkedin.github.io/greykite/docs/0.1.0/html/pages/model_components/0400_events.html
#   * Cutomized fit algorithm: https://linkedin.github.io/greykite/docs/0.1.0/html/pages/model_components/0600_custom.html
# * Greykite grid search reference: https://linkedin.github.io/greykite/docs/0.1.0/html/gallery/quickstart/0500_grid_search.html

# %%
import plotly
import pandas as pd
import matplotlib.pyplot as plt
from collections import defaultdict
from IPython.display import HTML

from greykite.framework.templates.autogen.forecast_config import ForecastConfig
from greykite.framework.templates.autogen.forecast_config import MetadataParam
from greykite.framework.templates.autogen.forecast_config import EvaluationPeriodParam
from greykite.framework.templates.autogen.forecast_config import ModelComponentsParam
from greykite.framework.templates.forecaster import Forecaster
from greykite.framework.templates.model_templates import ModelTemplateEnum
from greykite.framework.utils.result_summary import summarize_grid_search_results
from greykite.common.features.timeseries_features import get_available_holidays_across_countries

import warnings
warnings.filterwarnings("ignore")

# %%
def plot_ts(ts, title, exclude_cols):
    # %pylab inline
    plt.figure(figsize=(20,3))
    for col in ts.columns:
        if col in exclude_cols:
            continue
        fig = plt.plot(ts[col], label=col)
    plt.title(title)
    plt.legend(loc='best')
    plt.tight_layout()
    plt.show()

# %%
ts_df = pd.read_pickle('../../crystal_ball/data_collector/structured_data/sales_ts.pkl')
print(ts_df.shape)

ts_df.head()
# Out:
# (942, 1)
#             Daily_Sales
# Date
# 2013-01-01        58165
# 2013-01-02      4822042
# 2013-01-03      4415571
# 2013-01-04      4587035
# 2013-01-05      4078281

# %%
plot_ts(ts_df, title='Daily Sales', exclude_cols=['Date'])
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ts_df = ts_df.reset_index()
back_test_period = ts_df.loc[ts_df['Date'] >= '2015-03-01']['Date'].nunique()

print(back_test_period)
# Out:
# 153

# %% [markdown]
# ## Customize Model Components

# %%
# print out events strings
holiday_lookup_countries = ['China', 'US', 'Canada']

cross_country_holidays = get_available_holidays_across_countries(
    countries=holiday_lookup_countries,
    year_start=2013,
    year_end=2015)
print(cross_country_holidays)
# Out:
# ['Boxing Day', 'Boxing Day (Observed)', 'Canada Day', 'Chinese New Year', 'Christmas Day', 'Civic Holiday', 'Columbus Day', 'Dragon Boat Festival', 'Easter Monday', 'Family Day', 'Good Friday', 'Independence Day', 'Independence Day (Observed)', 'Labor Day', 'Labour Day', 'Martin Luther King Jr. Day', 'Memorial Day', 'Mid-Autumn Festival', 'National Day', "New Year's Day", 'Thanksgiving', 'Tomb-Sweeping Day', 'Veterans Day', 'Victoria Day', "Washington's Birthday"]

# %% [markdown]
# ### Silverkite Template

# %%
seasonality = dict(
     yearly_seasonality = "auto",
     quarterly_seasonality = [False, True], 
     monthly_seasonality = [2, 3],  # the value means # of weeks here, and the value can't be more than 4 since there are at most 4 weeks in a month
     weekly_seasonality = [True, False],
     daily_seasonality = False
)

events = dict(
    holidays_to_model_separately = ['Christmas Day', "New Year's Day", "Easter Monday", "Labour Day", "Labor Day"],
    holiday_lookup_countries = ['China', 'US', 'Canada'],
    holiday_pre_num_days=2,
    holiday_post_num_days=2,
)

custom = {
     "fit_algorithm_dict": [
         {"fit_algorithm": "ridge"},
         {"fit_algorithm": "gradient_boosting"},
         {"fit_algorithm": "rf"}
     ]
}


model_components = ModelComponentsParam(
     seasonality=seasonality,
     events=events,
     custom=custom
)

evaluation_period = EvaluationPeriodParam(
     test_horizon=back_test_period,  # # of days as testing data
     cv_horizon=back_test_period,  # # of days in CV validation data
     cv_max_splits=5,              # 5 folds CV
     cv_min_train_periods=back_test_period*3  # min # of days in CV training data
 )

metadata = MetadataParam(
     time_col="Date",
     value_col="Daily_Sales",
     freq="D"
)

config = ForecastConfig(
    model_template=ModelTemplateEnum.SILVERKITE.name,
    metadata_param=metadata,
    forecast_horizon=back_test_period,  # the number of steps to forecast ahead
    model_components_param=model_components,
    evaluation_period_param=evaluation_period
)

# %%
forecaster = Forecaster()  
result = forecaster.run_forecast_config(  
     df=ts_df,
     config=config
)
# Out:
# Fitting 2 folds for each of 24 candidates, totalling 48 fits

# %% [markdown]
# #### Cross Validation

# %%
grid_search = result.grid_search
cv_results = summarize_grid_search_results(
     grid_search=grid_search,
     decimals=2,
     cv_report_metrics=None,  # It saves space in the printed output. Remove to show all available metrics and columns.
     column_order=["rank", "mean_test", "split_test", "mean_train", "split_train", "mean_fit_time", "mean_score_time", "params"])

# Transposes to save space in the printed output
cv_results["params"] = cv_results["params"].astype(str)
cv_results.set_index("params", drop=True, inplace=True)
cv_results.transpose().T
# Out:
#                                                    rank_test_MAPE  \
# params
# [('estimator__weekly_seasonality', True), ('est...             18
# [('estimator__weekly_seasonality', False), ('es...             21
# [('estimator__weekly_seasonality', True), ('est...             20
# [('estimator__weekly_seasonality', False), ('es...             24
# [('estimator__weekly_seasonality', True), ('est...             17
# [('estimator__weekly_seasonality', False), ('es...             22
# [('estimator__weekly_seasonality', True), ('est...             19
# [('estimator__weekly_seasonality', False), ('es...             23
# [('estimator__weekly_seasonality', True), ('est...             10
# [('estimator__weekly_seasonality', False), ('es...             13
# [('estimator__weekly_seasonality', True), ('est...              2
# [('estimator__weekly_seasonality', False), ('es...             15
# [('estimator__weekly_seasonality', True), ('est...             12
# [('estimator__weekly_seasonality', False), ('es...             14
# [('estimator__weekly_seasonality', True), ('est...              8
# [('estimator__weekly_seasonality', False), ('es...             16
# [('estimator__weekly_seasonality', True), ('est...             11
# [('estimator__weekly_seasonality', False), ('es...              1
# [('estimator__weekly_seasonality', True), ('est...              9
# [('estimator__weekly_seasonality', False), ('es...              3
# [('estimator__weekly_seasonality', True), ('est...              7
# [('estimator__weekly_seasonality', False), ('es...              5
# [('estimator__weekly_seasonality', True), ('est...              6
# [('estimator__weekly_seasonality', False), ('es...              4
#
#                                                    mean_test_MAPE  \
# params
# [('estimator__weekly_seasonality', True), ('est...         142.79
# [('estimator__weekly_seasonality', False), ('es...         160.53
# [('estimator__weekly_seasonality', True), ('est...         145.54
# [('estimator__weekly_seasonality', False), ('es...         163.92
# [('estimator__weekly_seasonality', True), ('est...         142.69
# [('estimator__weekly_seasonality', False), ('es...         160.55
# [('estimator__weekly_seasonality', True), ('est...         145.15
# [('estimator__weekly_seasonality', False), ('es...          163.7
# [('estimator__weekly_seasonality', True), ('est...          77.53
# [('estimator__weekly_seasonality', False), ('es...         103.81
# [('estimator__weekly_seasonality', True), ('est...          72.75
# [('estimator__weekly_seasonality', False), ('es...         112.39
# [('estimator__weekly_seasonality', True), ('est...          79.37
# [('estimator__weekly_seasonality', False), ('es...         104.22
# [('estimator__weekly_seasonality', True), ('est...          76.89
# [('estimator__weekly_seasonality', False), ('es...         117.79
# [('estimator__weekly_seasonality', True), ('est...          77.81
# [('estimator__weekly_seasonality', False), ('es...          69.95
# [('estimator__weekly_seasonality', True), ('est...          77.12
# [('estimator__weekly_seasonality', False), ('es...          72.96
# [('estimator__weekly_seasonality', True), ('est...          76.36
# [('estimator__weekly_seasonality', False), ('es...          74.27
# [('estimator__weekly_seasonality', True), ('est...          75.78
# [('estimator__weekly_seasonality', False), ('es...          73.07
#
#                                                      split_test_MAPE  \
# params
# [('estimator__weekly_seasonality', True), ('est...  (114.57, 171.01)
# [('estimator__weekly_seasonality', False), ('es...  (144.82, 176.25)
# [('estimator__weekly_seasonality', True), ('est...   (119.88, 171.2)
# [('estimator__weekly_seasonality', False), ('es...  (152.28, 175.56)
# [('estimator__weekly_seasonality', True), ('est...   (114.4, 170.98)
# [('estimator__weekly_seasonality', False), ('es...  (145.09, 176.01)
# [('estimator__weekly_seasonality', True), ('est...  (119.72, 170.58)
# [('estimator__weekly_seasonality', False), ('es...  (152.14, 175.27)
# [('estimator__weekly_seasonality', True), ('est...    (91.92, 63.13)
# [('estimator__weekly_seasonality', False), ('es...   (145.55, 62.07)
# [('estimator__weekly_seasonality', True), ('est...    (84.37, 61.14)
# [('estimator__weekly_seasonality', False), ('es...    (162.88, 61.9)
# [('estimator__weekly_seasonality', True), ('est...    (98.46, 60.29)
# [('estimator__weekly_seasonality', False), ('es...   (144.15, 64.29)
# [('estimator__weekly_seasonality', True), ('est...    (96.23, 57.56)
# [('estimator__weekly_seasonality', False), ('es...   (172.81, 62.76)
# [('estimator__weekly_seasonality', True), ('est...    (70.86, 84.75)
# [('estimator__weekly_seasonality', False), ('es...     (73.49, 66.4)
# [('estimator__weekly_seasonality', True), ('est...    (68.31, 85.93)
# [('estimator__weekly_seasonality', False), ('es...     (70.2, 75.72)
# [('estimator__weekly_seasonality', True), ('est...    (69.72, 83.01)
# [('estimator__weekly_seasonality', False), ('es...     (74.2, 74.35)
# [('estimator__weekly_seasonality', True), ('est...     (65.46, 86.1)
# [('estimator__weekly_seasonality', False), ('es...    (74.12, 72.01)
#
#                                                    mean_train_MAPE  \
# params
# [('estimator__weekly_seasonality', True), ('est...           166.0
# [('estimator__weekly_seasonality', False), ('es...          187.54
# [('estimator__weekly_seasonality', True), ('est...          161.64
# [('estimator__weekly_seasonality', False), ('es...          176.06
# [('estimator__weekly_seasonality', True), ('est...          166.03
# [('estimator__weekly_seasonality', False), ('es...          187.46
# [('estimator__weekly_seasonality', True), ('est...          161.23
# [('estimator__weekly_seasonality', False), ('es...          175.74
# [('estimator__weekly_seasonality', True), ('est...            51.9
# [('estimator__weekly_seasonality', False), ('es...           57.72
# [('estimator__weekly_seasonality', True), ('est...           51.78
# [('estimator__weekly_seasonality', False), ('es...           57.75
# [('estimator__weekly_seasonality', True), ('est...           53.34
# [('estimator__weekly_seasonality', False), ('es...           55.52
# [('estimator__weekly_seasonality', True), ('est...           52.85
# [('estimator__weekly_seasonality', False), ('es...           58.27
# [('estimator__weekly_seasonality', True), ('est...           38.23
# [('estimator__weekly_seasonality', False), ('es...           37.62
# [('estimator__weekly_seasonality', True), ('est...           38.97
# [('estimator__weekly_seasonality', False), ('es...           39.14
# [('estimator__weekly_seasonality', True), ('est...           38.61
# [('estimator__weekly_seasonality', False), ('es...           39.23
# [('estimator__weekly_seasonality', True), ('est...           38.91
# [('estimator__weekly_seasonality', False), ('es...           37.86
#
#                                                     split_train_MAPE  \
# params
# [('estimator__weekly_seasonality', True), ('est...  (173.91, 158.09)
# [('estimator__weekly_seasonality', False), ('es...  (213.64, 161.44)
# [('estimator__weekly_seasonality', True), ('est...  (166.05, 157.24)
# [('estimator__weekly_seasonality', False), ('es...  (191.85, 160.28)
# [('estimator__weekly_seasonality', True), ('est...  (173.69, 158.37)
# [('estimator__weekly_seasonality', False), ('es...  (213.48, 161.43)
# [('estimator__weekly_seasonality', True), ('est...  (165.53, 156.93)
# [('estimator__weekly_seasonality', False), ('es...  (191.44, 160.04)
# [('estimator__weekly_seasonality', True), ('est...    (48.21, 55.59)
# [('estimator__weekly_seasonality', False), ('es...    (53.71, 61.74)
# [('estimator__weekly_seasonality', True), ('est...    (48.19, 55.37)
# [('estimator__weekly_seasonality', False), ('es...    (51.56, 63.95)
# [('estimator__weekly_seasonality', True), ('est...    (52.01, 54.67)
# [('estimator__weekly_seasonality', False), ('es...    (51.75, 59.29)
# [('estimator__weekly_seasonality', True), ('est...    (49.22, 56.47)
# [('estimator__weekly_seasonality', False), ('es...    (53.81, 62.73)
# [('estimator__weekly_seasonality', True), ('est...    (40.02, 36.44)
# [('estimator__weekly_seasonality', False), ('es...    (40.72, 34.52)
# [('estimator__weekly_seasonality', True), ('est...    (42.62, 35.33)
# [('estimator__weekly_seasonality', False), ('es...    (42.04, 36.23)
# [('estimator__weekly_seasonality', True), ('est...    (40.15, 37.06)
# [('estimator__weekly_seasonality', False), ('es...    (40.94, 37.52)
# [('estimator__weekly_seasonality', True), ('est...    (39.19, 38.63)
# [('estimator__weekly_seasonality', False), ('es...    (42.05, 33.67)
#
#                                                    mean_fit_time  \
# params
# [('estimator__weekly_seasonality', True), ('est...         12.45
# [('estimator__weekly_seasonality', False), ('es...         11.73
# [('estimator__weekly_seasonality', True), ('est...         12.03
# [('estimator__weekly_seasonality', False), ('es...         11.75
# [('estimator__weekly_seasonality', True), ('est...         10.85
# [('estimator__weekly_seasonality', False), ('es...          9.23
# [('estimator__weekly_seasonality', True), ('est...         10.74
# [('estimator__weekly_seasonality', False), ('es...         11.99
# [('estimator__weekly_seasonality', True), ('est...          2.82
# [('estimator__weekly_seasonality', False), ('es...          1.67
# [('estimator__weekly_seasonality', True), ('est...          2.35
# [('estimator__weekly_seasonality', False), ('es...          1.94
# [('estimator__weekly_seasonality', True), ('est...           1.8
# [('estimator__weekly_seasonality', False), ('es...          1.63
# [('estimator__weekly_seasonality', True), ('est...          1.93
# [('estimator__weekly_seasonality', False), ('es...          2.07
# [('estimator__weekly_seasonality', True), ('est...          3.22
# [('estimator__weekly_seasonality', False), ('es...          4.83
# [('estimator__weekly_seasonality', True), ('est...          6.23
# [('estimator__weekly_seasonality', False), ('es...          5.38
# [('estimator__weekly_seasonality', True), ('est...          5.16
# [('estimator__weekly_seasonality', False), ('es...          4.88
# [('estimator__weekly_seasonality', True), ('est...          5.85
# [('estimator__weekly_seasonality', False), ('es...          6.44
#
#                                                    mean_score_time
# params
# [('estimator__weekly_seasonality', True), ('est...            1.16
# [('estimator__weekly_seasonality', False), ('es...            1.19
# [('estimator__weekly_seasonality', True), ('est...            1.21
# [('estimator__weekly_seasonality', False), ('es...            1.09
# [('estimator__weekly_seasonality', True), ('est...            0.68
# [('estimator__weekly_seasonality', False), ('es...            0.68
# [('estimator__weekly_seasonality', True), ('est...            0.73
# [('estimator__weekly_seasonality', False), ('es...            1.26
# [('estimator__weekly_seasonality', True), ('est...            0.89
# [('estimator__weekly_seasonality', False), ('es...            0.58
# [('estimator__weekly_seasonality', True), ('est...            0.75
# [('estimator__weekly_seasonality', False), ('es...            0.65
# [('estimator__weekly_seasonality', True), ('est...             0.7
# [('estimator__weekly_seasonality', False), ('es...            0.61
# [('estimator__weekly_seasonality', True), ('est...            0.72
# [('estimator__weekly_seasonality', False), ('es...            0.84
# [('estimator__weekly_seasonality', True), ('est...            0.75
# [('estimator__weekly_seasonality', False), ('es...            1.22
# [('estimator__weekly_seasonality', True), ('est...            1.15
# [('estimator__weekly_seasonality', False), ('es...            1.13
# [('estimator__weekly_seasonality', True), ('est...            1.19
# [('estimator__weekly_seasonality', False), ('es...            1.16
# [('estimator__weekly_seasonality', True), ('est...            1.15
# [('estimator__weekly_seasonality', False), ('es...             1.3

# %% [markdown]
# #### Backtest

# %%
backtest = result.backtest
fig = backtest.plot()
plotly.io.show(fig)

# %%
backtest_eval = defaultdict(list)
for metric, value in backtest.train_evaluation.items():
    backtest_eval[metric].append(value)
    backtest_eval[metric].append(backtest.test_evaluation[metric])
metrics = pd.DataFrame(backtest_eval, index=["train", "test"]).T
metrics
# Out:
#                                                                   train  \
# CORR                                                           0.986988
# R2                                                             0.970405
# MSE                                                 132717672435.652008
# RMSE                                                      364304.367851
# MAE                                                       213330.459569
# MedAE                                                         121816.92
# MAPE                                                          29.373405
# MedAPE                                                         2.973471
# sMAPE                                                          4.058427
# Q80                                                       105598.552203
# Q95                                                       105065.213412
# Q99                                                       104922.989734
# OutsideTolerance1p                                             0.828897
# OutsideTolerance2p                                             0.637516
# OutsideTolerance3p                                             0.495564
# OutsideTolerance4p                                             0.377693
# OutsideTolerance5p                                             0.281369
# Outside Tolerance (fraction)                                       None
# R2_null_model_score                                                None
# Prediction Band Width (%)                                          None
# Prediction Band Coverage (fraction)                                None
# Coverage: Lower Band                                               None
# Coverage: Upper Band                                               None
# Coverage Diff: Actual_Coverage - Intended_Coverage                 None
#
#                                                                     test
# CORR                                                            0.885348
# R2                                                              0.755517
# MSE                                                 1259124264713.959961
# RMSE                                                      1122107.064729
# MAE                                                        678958.019608
# MedAE                                                           370986.8
# MAPE                                                           83.087884
# MedAPE                                                          8.504461
# sMAPE                                                           8.570081
# Q80                                                        438680.431529
# Q95                                                        488281.142392
# Q99                                                        501507.998622
# OutsideTolerance1p                                              0.934641
# OutsideTolerance2p                                              0.843137
# OutsideTolerance3p                                               0.79085
# OutsideTolerance4p                                              0.751634
# OutsideTolerance5p                                              0.686275
# Outside Tolerance (fraction)                                        None
# R2_null_model_score                                                 None
# Prediction Band Width (%)                                           None
# Prediction Band Coverage (fraction)                                 None
# Coverage: Lower Band                                                None
# Coverage: Upper Band                                                None
# Coverage Diff: Actual_Coverage - Intended_Coverage                  None

# %% [markdown]
# #### Forecast

# %%
forecast = result.forecast
fig = forecast.plot()
plotly.io.show(fig)

# %% [markdown]
# #### Model Summary

# %%
summary = result.model[-1].summary()  # -1 retrieves the estimator from the pipeline
print(summary.fit_algorithm, summary.ml_model)

coef_summary_df = summary.info_dict['coef_summary_df']
coef_summary_df = coef_summary_df.sort_values(by='Importance rank')
HTML(coef_summary_df.to_html())
# Out:
# rf RandomForestRegressor()
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Pred_col</th>
#       <th>Feature importance</th>
#       <th>Importance rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>36</th>
#       <td>C(Q('str_dow'), levels=['1-Mon', '2-Tue', '3-Wed', '4-Thu', '5-Fri', '6-Sat', '7-Sun'])[T.7-Sun]</td>
#       <td>3.255605e-01</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>C(Q('str_dow'), levels=['1-Mon', '2-Tue', '3-Wed', '4-Thu', '5-Fri', '6-Sat', '7-Sun'])[T.7-Sun]:ct1</td>
#       <td>2.874118e-01</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>ct1</td>
#       <td>3.555538e-02</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>sin1_ct1_yearly</td>
#       <td>1.716294e-02</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>73</th>
#       <td>sin13_ct1_yearly</td>
#       <td>1.685967e-02</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>cos1_ct1_yearly</td>
#       <td>1.642010e-02</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>C(Q('events_Easter Monday'), levels=['', 'event'])[T.event]</td>
#       <td>1.582376e-02</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>cos2_tom_monthly</td>
#       <td>1.223541e-02</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>72</th>
#       <td>cos12_ct1_yearly</td>
#       <td>1.087521e-02</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>C(Q('events_Labor Day'), levels=['', 'event'])[T.event]</td>
#       <td>1.011513e-02</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>sin4_ct1_yearly</td>
#       <td>9.826177e-03</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>sin5_ct1_yearly</td>
#       <td>9.008063e-03</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>sin8_ct1_yearly</td>
#       <td>8.730486e-03</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>70</th>
#       <td>cos11_ct1_yearly</td>
#       <td>8.550012e-03</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>cos3_ct1_yearly</td>
#       <td>8.427052e-03</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>sin3_ct1_yearly</td>
#       <td>8.183508e-03</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>C(Q('events_Christmas Day_plus_1'), levels=['', 'event'])[T.event]</td>
#       <td>8.027807e-03</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>cos1_tom_monthly</td>
#       <td>7.977165e-03</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>C(Q('str_dow'), levels=['1-Mon', '2-Tue', '3-Wed', '4-Thu', '5-Fri', '6-Sat', '7-Sun'])[T.6-Sat]:ct1</td>
#       <td>7.918877e-03</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>sin2_tom_monthly</td>
#       <td>7.778269e-03</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>cos9_ct1_yearly</td>
#       <td>7.496020e-03</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>sin7_ct1_yearly</td>
#       <td>7.355270e-03</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>74</th>
#       <td>cos13_ct1_yearly</td>
#       <td>7.347947e-03</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>sin6_ct1_yearly</td>
#       <td>7.345652e-03</td>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>69</th>
#       <td>sin11_ct1_yearly</td>
#       <td>7.040542e-03</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>sin2_ct1_yearly</td>
#       <td>6.846508e-03</td>
#       <td>26</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>cos6_ct1_yearly</td>
#       <td>6.837635e-03</td>
#       <td>27</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>C(Q('events_Other'), levels=['', 'event'])[T.event]</td>
#       <td>6.712621e-03</td>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>C(Q('str_dow'), levels=['1-Mon', '2-Tue', '3-Wed', '4-Thu', '5-Fri', '6-Sat', '7-Sun'])[T.4-Thu]:ct1</td>
#       <td>6.707354e-03</td>
#       <td>29</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>is_weekend[T.True]:ct1</td>
#       <td>6.225996e-03</td>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td>sin10_ct1_yearly</td>
#       <td>5.999932e-03</td>
#       <td>31</td>
#     </tr>
#     <tr>
#       <th>65</th>
#       <td>sin9_ct1_yearly</td>
#       <td>5.619752e-03</td>
#       <td>32</td>
#     </tr>
#     <tr>
#       <th>77</th>
#       <td>sin15_ct1_yearly</td>
#       <td>5.524230e-03</td>
#       <td>33</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>C(Q('str_dow'), levels=['1-Mon', '2-Tue', '3-Wed', '4-Thu', '5-Fri', '6-Sat', '7-Sun'])[T.6-Sat]</td>
#       <td>5.407681e-03</td>
#       <td>34</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>cos8_ct1_yearly</td>
#       <td>5.255766e-03</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>cos7_ct1_yearly</td>
#       <td>5.169179e-03</td>
#       <td>36</td>
#     </tr>
#     <tr>
#       <th>76</th>
#       <td>cos14_ct1_yearly</td>
#       <td>4.973683e-03</td>
#       <td>37</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>cos2_ct1_yearly</td>
#       <td>4.940988e-03</td>
#       <td>38</td>
#     </tr>
#     <tr>
#       <th>75</th>
#       <td>sin14_ct1_yearly</td>
#       <td>4.727494e-03</td>
#       <td>39</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>cos4_ct1_yearly</td>
#       <td>4.530459e-03</td>
#       <td>40</td>
#     </tr>
#     <tr>
#       <th>78</th>
#       <td>cos15_ct1_yearly</td>
#       <td>4.190885e-03</td>
#       <td>41</td>
#     </tr>
#     <tr>
#       <th>71</th>
#       <td>sin12_ct1_yearly</td>
#       <td>4.182381e-03</td>
#       <td>42</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>C(Q('str_dow'), levels=['1-Mon', '2-Tue', '3-Wed', '4-Thu', '5-Fri', '6-Sat', '7-Sun'])[T.5-Fri]:ct1</td>
#       <td>4.173535e-03</td>
#       <td>43</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>sin1_tom_monthly</td>
#       <td>4.028980e-03</td>
#       <td>44</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>cos5_ct1_yearly</td>
#       <td>3.946007e-03</td>
#       <td>45</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>C(Q('events_Christmas Day'), levels=['', 'event'])[T.event]</td>
#       <td>3.877553e-03</td>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>68</th>
#       <td>cos10_ct1_yearly</td>
#       <td>3.514649e-03</td>
#       <td>47</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>C(Q('events_Christmas Day_minus_2'), levels=['', 'event'])[T.event]</td>
#       <td>3.121450e-03</td>
#       <td>48</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>C(Q('str_dow'), levels=['1-Mon', '2-Tue', '3-Wed', '4-Thu', '5-Fri', '6-Sat', '7-Sun'])[T.2-Tue]:ct1</td>
#       <td>2.512631e-03</td>
#       <td>49</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>C(Q('events_Other_plus_2'), levels=['', 'event'])[T.event]</td>
#       <td>1.653037e-03</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>C(Q('str_dow'), levels=['1-Mon', '2-Tue', '3-Wed', '4-Thu', '5-Fri', '6-Sat', '7-Sun'])[T.3-Wed]:ct1</td>
#       <td>1.597759e-03</td>
#       <td>51</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>C(Q('str_dow'), levels=['1-Mon', '2-Tue', '3-Wed', '4-Thu', '5-Fri', '6-Sat', '7-Sun'])[T.2-Tue]</td>
#       <td>1.456398e-03</td>
#       <td>52</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>C(Q('events_Easter Monday_minus_2'), levels=['', 'event'])[T.event]</td>
#       <td>1.083613e-03</td>
#       <td>53</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>C(Q('str_dow'), levels=['1-Mon', '2-Tue', '3-Wed', '4-Thu', '5-Fri', '6-Sat', '7-Sun'])[T.4-Thu]</td>
#       <td>9.486517e-04</td>
#       <td>54</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>C(Q('str_dow'), levels=['1-Mon', '2-Tue', '3-Wed', '4-Thu', '5-Fri', '6-Sat', '7-Sun'])[T.5-Fri]</td>
#       <td>8.689889e-04</td>
#       <td>55</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>C(Q('events_New Years Day'), levels=['', 'event'])[T.event]</td>
#       <td>8.577162e-04</td>
#       <td>56</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>C(Q('events_New Years Day_minus_1'), level

# %%
summary.get_coef_summary(is_interaction=True, return_df=True)
# Out:
#          Pred_col Feature importance  Importance rank
#    is_weekend:ct1           0.006226               30
# str_dow_2-Tue:ct1           0.002513               49
# str_dow_3-Wed:ct1           0.001598               51
# str_dow_4-Thu:ct1           0.006707               29
# str_dow_5-Fri:ct1           0.004174               43
# str_dow_6-Sat:ct1           0.007919               19
# str_dow_7-Sun:ct1             0.2874                2
#             Pred_col  Feature importance  Importance rank  is_intercept  \
# 0     is_weekend:ct1            0.006226               30             0
# 1  str_dow_2-Tue:ct1            0.002513               49             0
# 2  str_dow_3-Wed:ct1            0.001598               51             0
# 3  str_dow_4-Thu:ct1            0.006707               29             0
# 4  str_dow_5-Fri:ct1            0.004174               43             0
# 5  str_dow_6-Sat:ct1            0.007919               19             0
# 6  str_dow_7-Sun:ct1            0.287412                2             0
#
#    is_time_feature  is_event  is_trend  is_seasonality  is_lag  is_regressor  \
# 0                1         0         1               0       0             0
# 1                1         0         1               0       0             0
# 2                1         0         1               0       0             0
# 3                1         0         1               0       0             0
# 4                1         0         1               0       0             0
# 5                1         0         1               0       0             0
# 6                1         0         1               0       0             0
#
#    is_interaction
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
# 5               1
# 6               1

# %% [markdown]
# ### Prophet Template

# %%
seasonality = dict(
     seasonality_mode=["multiplicative", "additive"],
     yearly_seasonality = True,
     weekly_seasonality = [True, False],
     daily_seasonality = False,
     add_seasonality_dict=[
        {
            'monthly': {
                'period': 365.25/12,
                'fourier_order': 2
            },
            'quarterly': {
                'period': 365.25/4,
                'fourier_order': 2
            }
        }]
)

events = dict(
    holiday_lookup_countries = ['China', 'US', 'Canada'],
    holiday_pre_num_days=[2],
    holiday_post_num_days=[2],
)

custom = {
     "fit_algorithm_dict": [
         {"fit_algorithm": "ridge"},
         {"fit_algorithm": "gradient_boosting"},
         {"fit_algorithm": "rf"}
     ]
}


model_components = ModelComponentsParam(
     seasonality=seasonality,
     events=events,
     custom=custom
)

evaluation_period = EvaluationPeriodParam(
     test_horizon=back_test_period,  # # of days as testing data
     cv_horizon=back_test_period,  # # of days in CV validation data
     cv_max_splits=5,              # 5 folds CV
     cv_min_train_periods=back_test_period*3  # min # of days in CV training data
 )

metadata = MetadataParam(
     time_col="Date",
     value_col="Daily_Sales",
     freq="D"
)

prophet_config = ForecastConfig(
    model_template=ModelTemplateEnum.PROPHET.name,
    coverage=0.95,  # this is mandatory for Prophet template
    metadata_param=metadata,
    forecast_horizon=back_test_period, 
    model_components_param=model_components,
    evaluation_period_param=evaluation_period
)

# %%
prophet_forecaster = Forecaster()  
prophet_result = prophet_forecaster.run_forecast_config(  
     df=ts_df,
     config=prophet_config
)
# Out:
# Fitting 2 folds for each of 4 candidates, totalling 8 fits

# %% [markdown]
# #### Cross Validation

# %%
grid_search = prophet_result.grid_search
cv_results = summarize_grid_search_results(
     grid_search=grid_search,
     decimals=2,
     cv_report_metrics=None,  # It saves space in the printed output. Remove to show all available metrics and columns.
     column_order=["rank", "mean_test", "split_test", "mean_train", "split_train", "mean_fit_time", "mean_score_time", "params"])

# Transposes to save space in the printed output
cv_results["params"] = cv_results["params"].astype(str)
cv_results.set_index("params", drop=True, inplace=True)
cv_results.transpose().T
# Out:
#                                                    rank_test_MAPE  \
# params
# [('estimator__weekly_seasonality', True), ('est...              1
# [('estimator__weekly_seasonality', False), ('es...              4
# [('estimator__weekly_seasonality', True), ('est...              2
# [('estimator__weekly_seasonality', False), ('es...              3
#
#                                                    mean_test_MAPE  \
# params
# [('estimator__weekly_seasonality', True), ('est...          73.36
# [('estimator__weekly_seasonality', False), ('es...         438.51
# [('estimator__weekly_seasonality', True), ('est...          98.56
# [('estimator__weekly_seasonality', False), ('es...         430.31
#
#                                                      split_test_MAPE  \
# params
# [('estimator__weekly_seasonality', True), ('est...    (90.91, 55.81)
# [('estimator__weekly_seasonality', False), ('es...  (419.89, 457.12)
# [('estimator__weekly_seasonality', True), ('est...   (90.73, 106.39)
# [('estimator__weekly_seasonality', False), ('es...  (410.27, 450.34)
#
#                                                    mean_train_MAPE  \
# params
# [('estimator__weekly_seasonality', True), ('est...           55.07
# [('estimator__weekly_seasonality', False), ('es...          432.78
# [('estimator__weekly_seasonality', True), ('est...           57.86
# [('estimator__weekly_seasonality', False), ('es...          423.28
#
#                                                     split_train_MAPE  \
# params
# [('estimator__weekly_seasonality', True), ('est...    (50.64, 59.51)
# [('estimator__weekly_seasonality', False), ('es...   (444.76, 420.8)
# [('estimator__weekly_seasonality', True), ('est...    (51.85, 63.87)
# [('estimator__weekly_seasonality', False), ('es...  (434.07, 412.49)
#
#                                                    mean_fit_time  \
# params
# [('estimator__weekly_seasonality', True), ('est...          4.09
# [('estimator__weekly_seasonality', False), ('es...          3.97
# [('estimator__weekly_seasonality', True), ('est...           2.0
# [('estimator__weekly_seasonality', False), ('es...          3.01
#
#                                                    mean_score_time
# params
# [('estimator__weekly_seasonality', True), ('est...            8.04
# [('estimator__weekly_seasonality', False), ('es...            8.58
# [('estimator__weekly_seasonality', True), ('est...            7.55
# [('estimator__weekly_seasonality', False), ('es...            7.09

# %% [markdown]
# #### Backtest

# %%
backtest = prophet_result.backtest
fig = backtest.plot()
plotly.io.show(fig)

# %%
backtest_eval = defaultdict(list)
for metric, value in backtest.train_evaluation.items():
    backtest_eval[metric].append(value)
    backtest_eval[metric].append(backtest.test_evaluation[metric])
metrics = pd.DataFrame(backtest_eval, index=["train", "test"]).T
metrics
# Out:
#                                                                   train  \
# CORR                                                           0.914744
# R2                                                             0.836756
# MSE                                                 732068389142.461548
# RMSE                                                      855609.951521
# MAE                                                       619166.854294
# MedAE                                                     475180.160546
# MAPE                                                          56.295009
# MedAPE                                                        13.385646
# sMAPE                                                         14.529816
# Q80                                                        309660.59271
# Q95                                                       309699.175491
# Q99                                                       309709.464233
# OutsideTolerance1p                                              0.96071
# OutsideTolerance2p                                             0.922687
# OutsideTolerance3p                                             0.875792
# OutsideTolerance4p                                               0.8327
# OutsideTolerance5p                                             0.785805
# Outside Tolerance (fraction)                                       None
# R2_null_model_score                                                None
# Prediction Band Width (%)                                    509.832317
# Prediction Band Coverage (fraction)                            0.958175
# Coverage: Lower Band                                           0.455006
# Coverage: Upper Band                                           0.503169
# Coverage Diff: Actual_Coverage - Intended_Coverage             0.008175
#
#                                                                     test
# CORR                                                            0.880416
# R2                                                              0.745347
# MSE                                                 1311501196980.720215
# RMSE                                                        1145207.9274
# MAE                                                        824761.712982
# MedAE                                                      633940.427449
# MAPE                                                           70.151531
# MedAPE                                                         15.813395
# sMAPE                                                          14.587945
# Q80                                                         523996.34789
# Q95                                                        579804.093589
# Q99                                                        594686.159109
# OutsideTolerance1p                                              0.973856
# OutsideTolerance2p                                              0.973856
# OutsideTolerance3p                                              0.947712
# OutsideTolerance4p                                              0.928105
# OutsideTolerance5p                                              0.875817
# Outside Tolerance (fraction)                                        None
# R2_null_model_score                                                 None
# Prediction Band Width (%)                                     450.471626
# Prediction Band Coverage (fraction)                             0.888889
# Coverage: Lower Band                                            0.320261
# Coverage: Upper Band                                            0.568627
# Coverage Diff: Actual_Coverage - Intended_Coverage             -0.061111

# %% [markdown]
# #### Forecast

# %%
forecast = prophet_result.forecast
fig = forecast.plot()
plotly.io.show(fig)
# Out:
# <div>                            <div id="63754232-7e1e-49be-b0eb-8bbd79343560" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("63754232-7e1e-49be-b0eb-8bbd79343560")) {                    Plotly.newPlot(                        "63754232-7e1e-49be-b0eb-8bbd79343560",                        [{"legendgroup":"interval","line":{"color":"rgba(0, 90, 181, 0.5)","width":0.0},"mode":"lines","name":"Lower Bound","x":["2013-01-01T00:00:00","2013-01-02T00:00:00","2013-01-03T00:00:00","2013-01-04T00:00:00","2013-01-05T00:00:00","2013-01-06T00:00:00","2013-01-07T00:00:00","2013-01-08T00:00:00","2013-01-09T00:00:00","2013-01-10T00:00:00","2013-01-11T00:00:00","2013-01-12T00:00:00","2013-01-13T00:00:00","2013-01-14T00:00:00","2013-01-15T00:00:00","2013-01-16T00:00:00","2013-01-17T00:00:00","2013-01-18T00:00:00","2013-01-19T00:00:00","2013-01-20T00:00:00","2013-01-21T00:00:00","2013-01-22T00:00:00","2013-01-23T00:00:00","2013-01-24T00:00:00","2013-01-25T00:00:00","2013-01-26T00:00:00","2013-01-27T00:00:00","2013-01-28T00:00:00","2013-01-29T00:00:00","2013-01-30T00:00:00","2013-01-31T00:00:00","2013-02-01T00:00:00","2013-02-02T00:00:00","2013-02-03T00:00:00","2013-02-04T00:00:00","2013-02-05T00:00:00","2013-02-06T00:00:00","2013-02-07T00:00:00","2013-02-08T00:00:00","2013-02-09T00:00:00","2013-02-10T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T00:00:00","2013-02-16T00:00:00","2013-02-17T00:00:00","2013-02-18T00:00:00","2013-02-19T00:00:00","2013-02-20T00:00:00","2013-02-21T00:00:00","2013-02-22T00:00:00","2013-02-23T00:00:00","2013-02-24T00:00:00","2013-02-25T00:00:00","2013-02-26T00:00:00","2013-02-27T00:00:00","2013-02-28T00:00:00","2013-03-01T00:00:00","2013-03-02T00:00:00","2013-03-03T00:00:00","2013-03-04T00:00:00","2013-03-05T00:00:00","2013-03-06T00:00:00","2013-03-07T00:00:00","2013-03-08T00:00:00","2013-03-09T00:00:00","2013-03-10T00:00:00","2013-03-11T00:00:00","2013-03-12T00:00:00","2013-03-13T00:00:00","2013-03-14T00:00:00","2013-03-15T00:00:00","2013-03-16T00:00:00","2013-03-17T00:00:00","2013-03-18T00:00:00","2013-03-19T00:00:00","2013-03-20T00:00:00","2013-03-21T00:00:00","2013-03-22T00:00:00","2013-03-23T00:00:00","2013-03-24T00:00:00","2013-03-25T00:00:00","2013-03-26T00:00:00","2013-03-27T00:00:00","2013-03-28T00:00:00","2013-03-29T00:00:00","2013-03-30T00:00:00","2013-03-31T00:00:00","2013-04-01T00:00:00","2013-04-02T00:00:00","2013-04-03T00:00:00","2013-04-04T00:00:00","2013-04-05T00:00:00","2013-04-06T00:00:00","2013-04-07T00:00:00","2013-04-08T00:00:00","2013-04-09T00:00:00","2013-04-10T00:00:00","2013-04-11T00:00:00","2013-04-12T00:00:00","2013-04-13T00:00:00","2013-04-14T00:00:00","2013-04-15T00:00:00","2013-04-16T00:00:00","2013-04-17T00:00:00","2013-04-18T00:00:00","2013-04-19T00:00:00","2013-04-20T00:00:00","2013-04-21T00:00:00","2013-04-22T00:00:00","2013-04-23T00:00:00","2013-04-24T00:00:00","2013-04-25T00:00:00","2013-04-26T00:00:00","2013-04-27T00:00:00","2013-04-28T00:00:00","2013-04-29T00:00:00","2013-04-30T00:00:00","2013-05-01T00:00:00","2013-05-02T00:00:00","2013-05-03T00:00:00","2013-05-04T00:00:00","2013-05-05T00:00:00","2013-05-06T00:00:00","2013-05-07T00:00:00","2013-05-08T00:00:00","2013-05-09T00:00:00","2013-05-10T00:00:00","2013-05-11T00:00:00","2013-05-12T00:00:00","2013-05-13T00:00:00","2013-05-14T00:00:00","2013-05-15T00:00:00","2013-05-16T00:00:00","2013-05-17T00:00:00","2013-05-18T00:00:00","2013-05-19T00:00:00","2013-05-20T00:00:00","2013-05-21T00:00:00","2013-05-22T00:00:00","2013-05-23T00:00:00","2013-05-24T00:00:00","2013-05-25T00:00:00","2013-05-26T00:00:00","2013-05-27T00:00:00","2013-05-28T00:00:00","2013-05-29T00:00:00","2013-05-30T00:00:00","2013-05-31T00:00:00","2013-06-01T00:00:00","2013 ...

# %% [markdown]
# #### Model Summary

# %%
prophet_result.model[-1]
# Out:
# ProphetEstimator(coverage=0.95, daily_seasonality=False,
#                  holidays=           ds                holiday  lower_window  upper_window
# 0  2016-01-01         New Year's Day            -2             2
# 1  2016-02-08       Chinese New Year            -2             2
# 2  2016-04-04      Tomb-Sweeping Day            -2             2
# 3  2016-04-05      Tomb-Sweeping Day            -2             2
# 4  2016-05-01              Labor Day            -2             2
# ..        ...                    ...           ...           ...
# 47 2015-07-01             Canada Day            -2             2
# 48 2015-09-07             Labour Day            -2             2
# 49 2015-10-12           Thanksgiving            -2             2
# 50 2015-11-11        Remembrance Day            -2             2
# 52 2015-12-28  Boxing Day (Observed)            -2             2
#
# [130 rows x 4 columns],
#                  score_func=<function add_finite_filter_to_scorer.<locals>.score_func_finite at 0x0000015F4F697E58>,
#                  seasonality_mode='multiplicative', weekly_seasonality=True,
#                  yearly_seasonality=True)
